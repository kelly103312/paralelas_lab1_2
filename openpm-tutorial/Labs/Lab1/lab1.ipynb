# %% [markdown]
# # Lab 1: Introduction to OpenMP
#
# The objective of this lab is to get familiar with the basic concepts behind OpenMP. Some of these concepts are shared with other programming models, and are important to understand how systems are programmed in parallel. These concepts are introduced directly using OpenMP syntax. It is not expected for the reader to know OpenMP, but they should be familiar with C-like syntax.
#
# This tutorial is expected to run in a unix-like environment.
#
# ## Table of content:
#
# * Thread and multithread
#     * First parallel program
#     * Thinking in parallel
#     * Exercise 1
# * Memory: Shared, private, distributed
#     * Atomic operations
#     * Private vs Firstprivate
#     * Reductions
#     * Lastprivate
#     * Exercise 2
# * OpenMP Syntax
# * Function outlining, implementation and runtime

# %% [markdown]
# ## Thread and multithreads
#
# Simply speaking, a thread is a worker that execute instructions. Current CPU architectures are mostly multi threaded, where each worker is independent to each other.
#
# Let's see how many cores are in our current system using `lscpu`.

# %%
# !lscpu
# Out:
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         48 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  6
#   On-line CPU(s) list:   0-5
# Vendor ID:               AuthenticAMD
#   Model name:            AMD FX(tm)-6300 Six-Core Processor
#     CPU family:          21
#     Model:               2
#     Thread(s) per core:  2
#     Core(s) per socket:  3
#     Socket(s):           1
#     Stepping:            0
#     BogoMIPS:            7031.55
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mc
#                          a cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall n
#                          x mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_go
#                          od nopl tsc_reliable nonstop_tsc cpuid extd_apicid pni
#                          pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 popcnt aes xsave
#                           avx f16c hypervisor lahf_lm cmp_legacy cr8_legacy abm
#                          sse4a misalignsse 3dnowprefetch osvw xop fma4 topoext s
#                          sbd ibpb vmmcall bmi1 virt_ssbd arat
# Virtualization features:
#   Hypervisor vendor:     Microsoft
#   Virtualization type:   full
# Caches (sum of all):
#   L1d:                   48 KiB (3 instances)
#   L1i:                   192 KiB (3 instances)
#   L2:                    6 MiB (3 instances)
#   L3:                    8 MiB (1 instance)
# Vulnerabilities:
#   Gather data sampling:  Not affected
#   Itlb multihit:         Not affected
#   L1tf:                  Not affected
#   Mds:                   Not affected
#   Meltdown:              Not affected
#   Mmio stale data:       Not affected
#   Retbleed:              Mitigation; untrained return thunk; SMT vulnerable
#   Spec rstack overflow:  Not affected
#   Spec store bypass:     Mitigation; Speculative Store Bypass disabled via prctl
#                           and seccomp
#   Spectre v1:            Mitigation; usercopy/swapgs barriers and __user pointer
#                           sanitization
#   Spectre v2:            Mitigation; Retpolines, IBPB conditional, STIBP disable
#                          d, RSB filling, PBRSB-eIBRS Not affected
#   Srbds:                 Not affected
#   Tsx async abort:       Not affected

# %% [markdown]
# In the output above you can find the number of CPUs (e.g. 8) and the number of Threads per CPU (e.g. 2). Each Thread is capable of independently handle a different stream of instructions. However, **software often creates more threads than available in the hardware system**.
#
# You can ignore the syntax in the following command, but its output will show the number of threads running within all processes in the system (or at least those that your user can obtain information about). __Most likely you will find that the number of *software* threads is much larger than the number of *hardware* threads. This is because the operating system uses a scheduling scheme to execute all the threads concurrently__.
#
# The focus of this lab is not to learn about OS threads, but it is worth knowing that the number of *software* threads in a given program can be larger than the number of *hardware* threads running in the system.

# %%
# !ps -eo nlwp | tail -n +2 | awk '{ num_threads += $1 } END { print num_threads }'
# Out:
# 22

# %% [markdown]
# ### Let's create our first threaded program
#
# ```C
# #include <omp.h>
#
# int main() {
#     #pragma omp parallel num_threads(10)
#     {
#         printf("Hello from thread %d\n",omp_get_thread_num());
#     }
#     return 0;
# }
# ```

# %%
# First, let's compile it
# !gcc -fopenmp C/parallel.c -o C/parallel.exe

# %%
# Now it is time to run it.
# !C/./parallel.exe
# Out:
# Hello from thread 1
# Hello from thread 3
# Hello from thread 4
# Hello from thread 2
# Hello from thread 5
# Hello from thread 0
# Hello from thread 9
# Hello from thread 8
# Hello from thread 6
# Hello from thread 7

# %% [markdown]
# You should immediately notice that (likely) the output of the above program is not in a given order. This is because all the threads are running concurrently, and, if the number of hardware threads is larger than 1, a set of them may be running in parallel.

# %% [markdown]
# ### Do it yourself
#
# Open the file [parallel.c](C/parallel.c) and play with different number of threads by changing the value inside the clause `num_threads()`, and re-running the above two commands.

# %% [markdown]
# ### Thinking in parallel
#
# If you're experienced in sequential programming, __you're likely familiar with writing code for a single thread.  When thinking sequentially, the developer must primarly think of the instructions that are executed. Parallel programming adds an additional complexity to the development program. When writting programs, a developer must think of the following aspects of the code__:
#
# * **Workers creation**: How to create workers and how many to create
# * **Work assignment**: How to assign work to different workers
# * **Workers/resources communication and coordination**: How workers communicate and synchronize in order to coordinate their work.
#
# ```
# Note: Different programming models exist that balance these three tasks. Here I am referring to the most popular programming models. Allow me to be simplistic here.
# ```

# %% [markdown]
# #### The fork-join model - An example.
#
# OpenMP is mainly known for its *Fork-Join* model. Programs execute with an initial sequential thread until a directive (code anotation) is reached that initiates parallel threads (workers). Different directives are used to assign work to these threads. At the end of the parallel region, threads synchronize, forming again a single thread.
#
# For the above example. **worker creation** is achieved through the `#pragma omp parallel num_threads(10)` directive. It allows to create 10 threads. Each worker is associated with an identifier, obtained through the `omp_get_thread_num()` function call. **Work assignment** is achieved through the code in the region enclosed by the brackets `{...}`. All threads are executing the same set of instructions, in this case only `printf("hello from thread %d\n",...);`. Notice that having a different identifier allows for each thread to access different data, or follow different paths. Finally **worker synchronization and coordination** is relatively simple in this example, since there's not much communication between them. However, at the end of the parallel region, all workers must wait for each other to finish before continuing with the sequential code.

# %% [markdown]
# ### Exercise 1
#
# Can you modify the code above to make the odd and even threads print something different?
#
# Go to [exercise1.c](Exercises/exercise1.c) and use the code region below to build and execute your code

# %%
# !gcc -fopenmp Exercises/exercise1.c -o Exercises/exercise1.exe && Exercises/./exercise1.exe
# Out:
# Hello from thread 1 IMPAR
# Hello from thread 4 PAR
# Hello from thread 5 IMPAR
# Hello from thread 3 IMPAR
# Hello from thread 7 IMPAR
# Hello from thread 9 IMPAR
# Hello from thread 6 PAR
# Hello from thread 8 PAR
# Hello from thread 2 PAR
# Hello from thread 0 PAR

# %% [markdown]
# ## Memory: Shared vs Private
#
# When programming we often imagine memory as a single "monolithic" element. However, this is not the reality. __Current architectures feature a complex memory organization that includes registers, caches, multiple DRAM banks__, and even devices with a different memory space. When programming in parallel, such complex structures become more important for correctness and performance.
#
# __Multithreading programming often features shared memory, meaning that all threads have access to the same varibles__, located in the same memory address (I expect the reader to be familiar with pointers). __However, it is also possible for each thread to have private memory, even if the name of variables are the same__.
#
# Take for example the next program:
#
# ```C
# int main() {
#     int i;
#     double share;
#     int Array[10];
#
#     printf("Address of i prior to the parallel region is: %lx\n",(unsigned long)&i);
#     printf("Address of shared prior to the parallel region is: %lx\n",(unsigned long)&share);
#     printf("Address of Array prior to the parallel region is: %lx\n",(unsigned long)Array);
#
#     #pragma omp parallel private(i, Array) shared(share)
#     {
#         printf("Address of i as seen by thread %d: %lx\n", omp_get_thread_num(), (unsigned long)&i);
#         printf("Address of Array as seen by thread %d: %lx\n", omp_get_thread_num(), (unsigned long)Array);
#         printf("Address of share as seen by thread %d: %lx\n", omp_get_thread_num(), (unsigned long)&share);
#     }
# }
# ```

# %%
# !gcc -fopenmp C/memory.c -o C/memory.exe

# %%
# !C/./memory.exe
# Out:
# Address of i prior to the parallel region is: 7ffe351c043c
# Address of shared prior to the parallel region is: 7ffe351c0440
# Address of Array prior to the parallel region is: 7ffe351c0450
# Address of i as seen by thread 0: 7ffe351c03ac
# Address of Array as seen by thread 0: 7ffe351c03b0
# Address of share as seen by thread 0: 7ffe351c0440
# Address of i as seen by thread 1: 7fa39d045dec
# Address of Array as seen by thread 1: 7fa39d045df0
# Address of share as seen by thread 1: 7ffe351c0440
# Address of i as seen by thread 3: 7fa39c043dec
# Address of Array as seen by thread 3: 7fa39c043df0
# Address of share as seen by thread 3: 7ffe351c0440
# Address of i as seen by thread 5: 7fa39b041dec
# Address of Array as seen by thread 5: 7fa39b041df0
# Address of share as seen by thread 5: 7ffe351c0440
# Address of i as seen by thread 4: 7fa39b842dec
# Address of Array as seen by thread 4: 7fa39b842df0
# Address of share as seen by thread 4: 7ffe351c0440
# Address of i as seen by thread 2: 7fa39c844dec
# Address of Array as seen by thread 2: 7fa39c844df0
# Address of share as seen by thread 2: 7ffe351c0440

# %% [markdown]
# You can play with this code going to [memory.c](C/memory.c)

# %% [markdown]
# __Private memory allows for variables to be visible only by the current worker. Shared memory, allows variables to be visible from and modified by multiple workers (read and write)__. However, it is important to be careful. As previously mentioned, memory organization is complex, and requires additional coordination.
#
# Take for example the following program:
#
# ```C
# int main() {
#     int i = 0;
#
#     #pragma omp parallel shared(i) num_threads(10000)
#     {
#         i++;
#     }
#
#     printf("i = %d\n",i);
#     return 0;
# }
# ```

# %%
# !gcc -fopenmp C/datarace.c -o C/datarace.exe

# %%
# !C/./datarace.exe
# Out:
# i = 9873

# %% [markdown]
# If 10000 workers are created, and each is adding 1 to the value of i, the "expected" value would be 10000. If you're running this in a machine that has multiple threads, I expect you to see a number less than 10000. Moreover, multiple executions may lead to different results. This is what is known as a **data race**. It occurs because reading i, incrementing, and writting to i are three different instructions. Therefore, it is possible for two threads to write the same value of i, increment it and obtain the same value twice.
#
# For this reason, __shared memory requires additional coordination between workers__, such that reads and writes to the same region are perceived in the expected order.
#
# Notice that this is part of thinking about **workers/resource communication and coordination**. We are coordinating memory acesses and operations to variables, as they are shared across different workers.
#
# You can modify the above code going to [datarace.c](C/datarace.c)
#
# ```
# Note: Data races are a difficult aspect of parallel programming. Multiple executions may lead to different results, but among the different results that can be obtained, it is still possible to obtain the "expected" result. Some data races are more difficult to debug than others, because they have a higher chance of choosing the "expected" result. Imagine that 1 out of a million executions of your code in a given hardware shows a datarace. Now imagine this program running the automatic pilot of an airplane...
# ```

# %% [markdown]
# ### Atomic operations
#
# __Atomic operations allows different threads to perform different operations to the same memory location in a single instruction (or as if they were executed in a single instruction)__. In the example above, atomic operations would allow for read, increment and write to happen in a single instruction (or "atomically"). Thus, atomic operations can solve the datarace issue of the previous example.

# %% [markdown]
# ```C
# int main() {
#     int i = 0;
#
#     #pragma omp parallel shared(i) num_threads(10000)
#     {
#         #pragma omp atomic
#         i++;
#     }
#
#     printf("i = %d\n",i);
#     return 0;
# }
# ```

# %%
# !gcc -fopenmp C/atomic.c -o C/atomic.exe

# %%
# !C/./atomic.exe
# Out:
# i = 10000

# %% [markdown]
# You can play with the above code going to [atomic.c](C/atomic.c)

# %% [markdown]
# ### Private vs Firstprivate
#
# Privatization of variables means that a single variable name will have different memory locations. Privatization does not guarantee that the new address has the same value of the original address (i.e. the address before the parallel region).
#
# Take for example the following code:

# %% [markdown]
# ```C
# int main() {
#     int i = 999;
#
#     printf("i is %d before parallel region\n",i);
#
#     #pragma omp parallel private(i) num_threads(10)
#     {
#         printf("Thread %d sees %d on memory %lx\n", omp_get_thread_num(), i, (unsigned long)&i);
#     }
#
#     return 0;
# }
# ```

# %%
# !gcc -fopenmp C/private.c -o C/private.exe

# %%
# !C/./private.exe
# Out:
# i is 999 before parallel region
# Thread 9 sees 0 on memory 7f1f1e13fd74
# Thread 3 sees 0 on memory 7f1f21145d74
# Thread 5 sees 0 on memory 7f1f20143d74
# Thread 6 sees 0 on memory 7f1f1f942d74
# Thread 7 sees 0 on memory 7f1f1f141d74
# Thread 1 sees 0 on memory 7f1f22147d74
# Thread 4 sees 0 on memory 7f1f20944d74
# Thread 2 sees 0 on memory 7f1f21946d74
# Thread 0 sees 0 on memory 7ffef83e17a4
# Thread 8 sees 0 on memory 7f1f1e940d74

# %% [markdown]
# You can play with the above code going to [private.c](C/private.c)

# %% [markdown]
# Firstprivate allows for each new address location to be initialized with the value prior to the parallel region. Take for example the following code.
#
# ```C
# int main() {
#     int i[3] = {999,888,666};
#
#     printf("i is [%d,%d,%d] before parallel region\n",i[0],i[1],i[2]);
#
#     #pragma omp parallel firstprivate(i) num_threads(10)
#     {
#         printf("Thread %d sees [%d,%d,%d] on memory %lx\n", omp_get_thread_num(), i[0],i[1],i[2], (unsigned long)i);
#     }
#
#     return 0;
# }
# ```

# %%
# !gcc -fopenmp C/firstprivate.c -o C/firstprivate.exe

# %%
# !C/./firstprivate.exe
# Out:
# i is [999,888,666] before parallel region
# Thread 0 sees [999,888,666] on memory 7ffcc7ca4e7c
# Thread 5 sees [999,888,666] on memory 7f72b4e9fdfc
# Thread 9 sees [999,888,666] on memory 7f72b2e9bdfc
# Thread 6 sees [999,888,666] on memory 7f72b469edfc
# Thread 8 sees [999,888,666] on memory 7f72b369cdfc
# Thread 4 sees [999,888,666] on memory 7f72b56a0dfc
# Thread 7 sees [999,888,666] on memory 7f72b3e9ddfc
# Thread 2 sees [999,888,666] on memory 7f72b66a2dfc
# Thread 1 sees [999,888,666] on memory 7f72b6ea3dfc
# Thread 3 sees [999,888,666] on memory 7f72b5ea1dfc

# %% [markdown]
# You can play with the above code going to [firstprivate.c](C/firstprivate.c)
#
# Notice how each location for i is different on each thread, yet, all have the same expected value. __This also means that memory copies need to be performed in order to achieve this behavior. Hence, if your array is large, it may incur in additional overhead__.
#
# There are still a lot of good reasons to privatize variables.

# %% [markdown]
# ### Reductions
#
# So far we have discussed what happens to variables when going from a sequential region to a parallel region. However, what happens to these multiple private memory locations when a parallel region is over? In principle, private variables are discarded (freed) at the end of a parallel region, hence, if their value are important, it is necessary to store them into a shared location that lives after the parallel region. Yet, it is often desireable to update the original memory location of the variable.
#
# But wait, all of these variables may have different values. How do I decide what's the final value to be used after the parallel region? Reductions are collective operations that aggregate the different values into a single value, by applying an operation. Ideally, this operation should be commutative, otherwise, how do I decide the order in which they are applied?
#
# ```
# Note: Surprisingly enough OpenMP used to support the minus (-) operation for reductions. It wasn't until version 5.2 that they removed support for this operation. If thread 1 and thread 2 are reducing A, should it be At1 - At2 or At2 - At1?
# ```

# %% [markdown]
# Let's take for example the following code:
#
# ```C
# int main() {
#     int i = 99;
#
#     printf("Value if i prior to parallel region is %d\n",i);
#
#     // Private values are not transferred back
#     #pragma omp parallel private(i)
#     {
#         i=1000;
#     }
#     printf("Value if i after parallel region with private(i) is %d\n",i);
#
#     i = 0;
#     // Reductions for addition.
#     #pragma omp parallel reduction(+:i) num_threads(10)
#     {
#         i=1;
#     }
#     printf("Value if i after parallel region with reduction(+:i) is %d\n",i);
#
#     // Reductions for max.
#     #pragma omp parallel reduction(max:i) num_threads(20)
#     {
#         i=omp_get_thread_num();
#     }
#     printf("Value if i after parallel region with reduction(max:i) is %d\n",i);
#
#     return 0;
# }
# ```

# %%
# !gcc -fopenmp C/reductions.c -o C/reductions.exe

# %%
# !C/./reductions.exe
# Out:
# Value if i prior to parallel region is 99
# Value if i after parallel region with private(i) is 99
# Value if i after parallel region with reduction(+:i) is 10
# Value if i after parallel region with reduction(max:i) is 19

# %% [markdown]
# You can play with the above code going to [reductions.c](C/reductions.c). Other reduction operations are:
# * Multiplication (*)
# * Minimun (min)
# * Bitwise AND (&)
# * Bitwise OR (|)
# * Bitwise XOR (^)
# * Logic AND (&&)
# * Logic OR (&&)

# %% [markdown]
# ### Lastprivate
#
# Finally, there is lastprivate. Later on we will discuss more about loops and how to distribute them across workers. However, lastprivate allows for the value to be the last value in the iteration space. This means, if we have 10 iterations in a for loop, the value for i = 9 will be copied over.
#
# This code shows this behavior. Let us ignore for now the `for` construct. We will go back to it later on.
#
# ```C
#     int Array[10];
#     int i, b;
#
#     for (i = 0; i < 10; i++) {
#         Array[i] = i;
#     }
#
#     #pragma omp parallel for lastprivate(b)
#     for (i = 0; i < 10; i++)
#     {
#         b = Array[i];
#     }
#     printf("b is %d after the parallel region\n", b);
#
#     return 0;
# ```

# %%
# !gcc -fopenmp C/lastprivate.c -o C/lastprivate.exe

# %%
# !C/./lastprivate.exe
# Out:
# b is 9 after the parallel region

# %% [markdown]
# You can play with this code going to [lastprivate.c](C/lastprivate.c).

# %% [markdown]
# ### Exercise 2
#
# Create a program that:
# 1. Initializes an array of 100 elements to random numbers by assigning a thread per element of the array.
# 2. Finds the max value of the array.
# 3. Finds the min value of the array.
# 4. Finds the average value of the array.
#
# Go to [exercise2.c](Exercises/exercise2.c) and use the code region below to build and execute your code

# %%
# !gcc -fopenmp Exercises/exercise2.c -o Exercises/exercise2.exe && Exercises/./exercise2.exe
# Out:
# Valor dato  0 max 0 min 100000
# Valor dato  0 max 0 min 100000
# Valor dato  27 max 492 min 27
# Valor dato  27 max 492 min 27
# Valor dato  3426 max 3426 min 27
# Valor dato  0 max 0 min 100000
# Valor dato  5211 max 5736 min 27
# Valor dato  4067 max 5736 min 27
# Valor dato  3058 max 5736 min 27
# Valor dato  8456 max 8456 min 27
# Valor dato  8456 max 8456 min 27
# Valor dato  7373 max 8456 min 27
# Valor dato  0 max 8537 min 27
# Valor dato  0 max 8537 min 27
# Valor dato  4324 max 8537 min 27
# Valor dato  492 max 492 min 492
# Valor dato  8315 max 8537 min 27
# Valor dato  8315 max 9956 min 27
# Valor dato  3526 max 9956 min 27
# Valor dato  0 max 5736 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  5211 max 5736 min 27
# Valor dato  5211 max 5736 min 27
# Valor dato  27 max 492 min 27
# Valor dato  925 max 9956 min 27
# Valor dato  5211 max 5736 min 27
# Valor dato  6505 max 9956 min 27
# Valor dato  4067 max 5736 min 27
# Valor dato  5211 max 5736 min 27
# Valor dato  492 max 492 min 492
# Valor dato  1729 max 9956 min 27
# Valor dato  7178 max 9956 min 27
# Valor dato  7178 max 9956 min 27
# Valor dato  5060 max 9956 min 27
# Valor dato  5060 max 9956 min 27
# Valor dato  8440 max 9956 min 27
# Valor dato  0 max 8456 min 27
# Valor dato  7281 max 9956 min 27
# Valor dato  7084 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 27
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 8537 min 27
# Valor dato  4481 max 9956 min 19
# Valor dato  709 max 9956 min 19
# Valor dato  8927 max 9956 min 19
# Valor dato  4567 max 9956 min 19
# Valor dato  7856 max 9956 min 19
# Valor dato  9497 max 9956 min 19
# Valor dato  5732 max 9956 min 19
# Valor dato  8829 max 9956 min 19
# Valor dato  9503 max 9956 min 19
# Valor dato  19 max 9956 min 19
# Valor dato  8270 max 9956 min 19
# Valor dato  3368 max 9956 min 19
# Valor dato  9708 max 9956 min 19
# Valor dato  6715 max 9956 min 19
# Valor dato  6340 max 9956 min 19
# Valor dato  8149 max 9956 min 19
# Valor dato  7796 max 9956 min 19
# Valor dato  723 max 9956 min 19
# Valor dato  2618 max 9956 min 19
# Valor dato  2245 max 9956 min 19
# Valor dato  2846 max 9956 min 19
# Valor dato  3451 max 9956 min 19
# Valor dato  2921 max 9956 min 19
# Valor dato  3555 max 9956 min 19
# Valor dato  2379 max 9956 min 19
# Valor dato  7488 max 9956 min 19
# Valor dato  7764 max 9956 min 19
# Valor dato  925 max 9956 min 27
# Valor dato  5856 max 9956 min 19
# Valor dato  3743 max 9956 min 19
# Valor dato  6491 max 9956 min 19
# Valor dato  2227 max 9956 min 19
# Valor dato  8365 max 9956 min 19
# Valor dato  9859 max 9956 min 19
# Valor dato  1936 max 9956 min 19
# Valor dato  1432 max 9956 min 19
# Valor dato  2551 max 9956 min 19
# Valor dato  6437 max 9956 min 19
# Valor dato  9228 max 9956 min 19
# Valor dato  7281 max 9956 min 27
# Valor dato  1729 max 9956 min 27
# Valor dato  4443 max 9956 min 19
# Valor dato  5763 max 9956 min 19
# Valor dato  4613 max 9956 min 19
# Valor dato  5857 max 9956 min 27
# Valor dato  5857 max 9956 min 27
# Valor dato  6996 max 9956 min 19
# Valor dato  8814 max 9956 min 27
# Valor dato  7369 max 9956 min 19
# Valor dato  8814 max 9956 min 27
# Valor dato  2183 max 9956 min 19
# Valor dato  5499 max 9956 min 19
# Valor dato  7917 max 9956 min 19
# Valor dato  9917 max 9956 min 19
# Valor dato  3324 max 9956 min 19
# Valor dato  4538 max 9956 min 19
# Valor dato  8606 max 9956 min 19
# Valor dato  6840 max 9956 min 19
# Valor dato  2904 max 9956 min 19
# Valor dato  4818 max 9956 min 19
# Valor dato  5128 max 9956 min 19
# Valor dato  688 max 9956 min 19
# Valor dato  3275 max 9956 min 19
# Valor dato  5407 max 9956 min 19
# Valor dato  1474 max 9956 min 19
# Valor dato  6121 max 9956 min 19
# Valor dato  8858 max 9956 min 19
# Valor dato  4395 max 9956 min 19
# Valor dato  6029 max 9956 min 19
# Valor dato  1237 max 9956 min 19
# Valor dato  8235 max 9956 min 19
# Valor dato  3793 max 9956 min 19
# Valor dato  5818 max 9956 min 19
# Valor dato  4428 max 9956 min 19
# Valor dato  6143 max 9956 min 19
# Valor dato  1011 max 9956 min 19
# Valor dato  5928 max 9956 min 19
# Valor dato  8776 max 9956 min 19
# Valor dato  8228 max 9956 min 19
# Valor dato  9841 max 9956 min 19
# Valor dato  2350 max 9956 min 19
# Valor dato  5193 max 9956 min 19
# Valor dato  1500 max 9956 min 19
# Valor dato  7034 max 9956 min 19
# Valor dato  7764 max 9956 min 19
# Valor dato  124 max 9956 min 19
# Valor dato  4914 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  7178 max 9956 min 27
# Valor dato  6725 max 9956 min 19
# Valor dato  5644 max 9956 min 19
# Valor dato  5590 max 9956 min 19
# Valor dato  7505 max 9956 min 19
# Valor dato  4043 max 9956 min 27
# Valor dato  0 max 0 min 100000
# Valor dato  2062 max 9956 min 19
# Valor dato  5624 max 9956 min 19
# Valor dato  2600 max 9956 min 19
# Valor dato  7505 max 9956 min 19
# Valor dato  8139 max 9956 min 19
# Valor dato  2954 max 9956 min 19
# Valor dato  973 max 9956 min 19
# Valor dato  2954 max 9956 min 19
# Valor dato  0 max 5736 min 27
# Valor dato  5060 max 9956 min 27
# Valor dato  5894 max 9956 min 19
# Valor dato  5550 max 9956 min 19
# Valor dato  7468 max 9956 min 19
# Valor dato  7131 max 9956 min 19
# Valor dato  3881 max 9956 min 19
# Valor dato  8933 max 9956 min 19
# Valor dato  9786 max 9956 min 19
# Valor dato  7669 max 9956 min 19
# Valor dato  8082 max 9956 min 19
# Valor dato  8542 max 9956 min 19
# Valor dato  8464 max 9956 min 19
# Valor dato  197 max 9956 min 19
# Valor dato  9507 max 9956 min 19
# Valor dato  9355 max 9956 min 19
# Valor dato  8804 max 9956 min 19
# Valor dato  6348 max 9956 min 19
# Valor dato  8611 max 9956 min 19
# Valor dato  3622 max 9956 min 19
# Valor dato  7828 max 9956 min 19
# Valor dato  9299 max 9956 min 19
# Valor dato  7343 max 9956 min 19
# Valor dato  5746 max 9956 min 19
# Valor dato  5568 max 9956 min 19
# Valor dato  4340 max 9956 min 19
# Valor dato  5060 max 9956 min 27
# Valor dato  163 max 9956 min 19
# Valor dato  7199 max 9956 min 19
# Valor dato  7981 max 9956 min 19
# Valor dato  8899 max 9956 min 19
# Valor dato  2996 max 9956 min 19
# Valor dato  2959 max 9956 min 19
# Valor dato  3773 max 9956 min 19
# Valor dato  2813 max 9956 min 19
# Valor dato  9668 max 9956 min 19
# Valor dato  7190 max 9956 min 19
# Valor dato  1095 max 9956 min 19
# Valor dato  2926 max 9956 min 19
# Valor dato  6466 max 9956 min 19
# Valor dato  5084 max 9956 min 19
# Valor dato  1340 max 9956 min 19
# Valor dato  2090 max 9956 min 19
# Valor dato  7684 max 9956 min 19
# Valor dato  3376 max 9956 min 19
# Valor dato  5542 max 9956 min 19
# Valor dato  5936 max 9956 min 19
# Valor dato  9107 max 9956 min 19
# Valor dato  7445 max 9956 min 19
# Valor dato  9756 max 9956 min 19
# Valor dato  9179 max 9956 min 19
# Valor dato  5422 max 9956 min 19
# Valor dato  3311 max 9956 min 19
# Valor dato  3810 max 9956 min 19
# Valor dato  7605 max 9956 min 19
# Valor dato  1801 max 9956 min 19
# Valor dato  5661 max 9956 min 19
# Valor dato  3730 max 9956 min 19
# Valor dato  4878 max 9956 min 19
# Valor dato  1305 max 9956 min 19
# Valor dato  9320 max 9956 min 19
# Valor dato  8736 max 9956 min 19
# Valor dato  9444 max 9956 min 19
# Valor dato  8626 max 9956 min 19
# Valor dato  8522 max 9956 min 19
# Valor dato  3465 max 9956 min 19
# Valor dato  6708 max 9956 min 19
# Valor dato  3416 max 9956 min 19
# Valor dato  8282 max 9956 min 19
# Valor dato  3258 max 9956 min 19
# Valor dato  2924 max 9956 min 19
# Valor dato  2036 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  6 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9956 min 19
# Valor dato  0 max 9958 min 19
# Valor dato  0 max 9958 min 19
# Valor dato  0 max 9958 min 19
# Valor dato  0 max 9958 min 19
# Valor dato  8440 max 9956 min 27
# Valor dato  6887 max 9958 min 19
# Valor dato  9412 max 9958 min 19
# Valor dato  3348 max 9958 min 19
# Valor dato  2172 max 9958 min 19
# Valor dato  1659 max 9958 min 19
# Valor dato  2009 max 9958 min 19
# Valor dato  2336 max 9958 min 19
# Valor dato  5210 max 9958 min 19
# Valor dato  6342 max 9958 min 19
# Valor dato  7587 max 9958 min 19
# Valor dato  8206 max 9958 min 19
# Valor dato  9301 max 9958 min 19
# Valor dato  7713 max 9958 min 19
# Valor dato  7372 max 9958 min 19
# Valor dato  5321 max 9958 min 19
# Valor dato  1255 max 9958 min 19
# Valor dato  4819 max 9958 min 19
# Valor dato  4599 max 9958 min 19
# Valor dato  7721 max 9958 min 19
# Valor dato  9904 max 9958 min 19
# Valor dato  5939 max 9958 min 19
# Valor dato  9811 max 9958 min 19
# Valor dato  3940 max 9958 min 19
# Valor dato  0 max 8456 min 27
# Valor dato  3303 max 9958 min 19
# Valor dato  0 max 8456 min 27
# Valor dato  3303 max 9958 min 19
# Valor dato  3333 max 9958 min 19
# Valor dato  2353 max 9956 min 27
# Valor dato  9125 max 9958 min 19
# Valor dato  3996 max 9958 min 19
# Valor dato  5975 max 9958 min 19
# Valor dato  2133 max 9958 min 19
# Valor dato  1648 max 9958 min 19
# Valor dato  2890 max 9958 min 19
# Valor dato  9754 max 9958 min 19
# Valor dato  7567 max 9958 min 19
# Valor dato  1746 max 9958 min 19
# Valor dato  368 max 9958 min 19
# Valor dato  9529 max 9958 min 19
# Valor dato  4500 max 9958 min 19
# Valor dato  8046 max 9958 min 19
# Valor dato  3788 max 9958 min 19
# Valor dato  9797 max 9958 min 19
# Valor dato  6249 max 9958 min 19
# Valor dato  6990 max 9958 min 19
# Valor dato  3303 max 9958 min 19
# Valor dato  3033 max 9958 min 19
# Valor dato  5363 max 9958 min 19
# Valor dato  2497 max 9958 min 19
# Valor dato  253 max 9958 min 19
# Valor dato  7686 max 9958 min 19
# Valor dato  5667 max 9958 min 19
# Valor dato  1705 max 9958 min 19
# Valor dato  6228 max 9958 min 19
# Valor dato  1127 max 9958 min 19
# Valor dato  9150 max 9958 min 19
# Valor dato  5984 max 9958 min 19
# Valor dato  6658 max 9958 min 19
# Valor dato  3920 max 9958 min 19
# Valor dato  9224 max 9958 min 19
# Valor dato  2422 max 9958 min 19
# Valor dato  7269 max 9958 min 19
# Valor dato  1396 max 9958 min 19
# Valor dato  4081 max 9958 min 19
# Valor dato  5630 max 9958 min 19
# Valor dato  84 max 9958 min 19
# Valor dato  9292 max 9958 min 19
# Valor dato  1972 max 9958 min 19
# Valor dato  4683 max 9956 min 27
# Valor dato  7672 max 9958 min 19
# Valor dato  3850 max 9958 min 19
# Valor dato  7625 max 9958 min 19
# Valor dato  5385 max 9958 min 19
# Valor dato  1222 max 9958 min 19
# Valor dato  9299 max 9958 min 19
# Valor dato  6640 max 9958 min 19
# Valor dato  6042 max 9958 min 19
# Valor dato  4683 max 9956 min 27
# Valor dato  9157 max 9958 min 19
# Valor dato  3729 max 9958 min 19
# Valor dato  5436 max 9958 min 19
# Valor dato  2460 max 9958 min 19
# Valor dato  3414 max 9958 min 19
# Valor dato  3921 max 9958 min 19
# Valor dato  460 max 9958 min 19
# Valor dato  6304 max 9958 min 19
# Valor dato  28 max 9958 min 19
# Valor dato  8027 max 9958 min 19
# Valor dato  8050 max 9958 min 19
# Valor dato  6748 max 9958 min 19
# Valor dato  7556 max 9958 min 19
# Valor dato  8902 max 9958 min 19
# Valor dato  4794 max 9958 min 19
# Valor dato  7697 max 9958 min 19
# Valor dato  8699 max 9958 min 19
# Valor dato  1043 max 9958 min 19
# Valor dato  1039 max 9958 min 19
# Valor dato  2002 max 9958 min 19
# Valor dato  428 max 9958 min 19
# Valor dato  6403 max 9958 min 19
# Valor dato  4500 max 9958 min 19
# Valor dato  681 max 9958 min 19
# Valor dato  7647 max 9958 min 19
# Valor dato  8538 max 9958 min 19
# Valor dato  6159 max 9958 min 19
# Valor dato  5151 max 9958 min 19
# Valor dato  2535 max 9958 min 19
# Valor dato  2134 max 9958 min 19
# Valor dato  4339 max 9958 min 19
# Valor dato  1692 max 9958 min 19
# Valor dato  2215 max 9958 min 19
# Valor dato  6127 max 9958 min 19
# Valor dato  504 max 9958 min 19
# Valor dato  5629 max 9958 min 19
# Valor dato  49 max 9958 min 19
# Valor dato  964 max 9958 min 19
# Valor dato  8285 max 9958 min 19
# Valor dato  6429 max 9958 min 19
# Valor dato  5343 max 9958 min 19
# Valor dato  6335 max 9958 min 19
# Valor dato  3177 max 9958 min 19
# Valor dato  2900 max 9958 min 19
# Valor dato  5238 max 9958 min 19
# Valor dato  7971 max 9958 min 19
# Valor dato  6949 max 9958 min 19
# Valor dato  5367 max 9958 min 19
# Valor dato  3898 max 9958 min 19
# Valor dato  713 max 9958 min 19
# Valor dato  2298 max 9958 min 19
# Valor dato  6190 max 9958 min 19
# Valor dato  524 max 9958 min 19
# Valor dato  2590 max 9958 min 19
# Valor dato  8209 max 9958 min 19
# Valor dato  8581 max 9958 min 19
# Valor dato  8819 max 9958 min 19
# Valor dato  9336 max 9958 min 19
# Valor dato  7732 max 9958 min 19
# Valor dato  1155 max 9958 min 19
# Valor dato  5994 max 9958 min 19
# Valor dato  8004 max 9958 min 19
# Valor dato  379 max 9958 min 19
# Valor dato  4769 max 9958 min 19
# Valor dato  5273 max 9958 min 19
# Valor dato  1776 max 9958 min 19
# Valor dato  8850 max 9958 min 19
# Valor dato  7255 max 9958 min 19
# Valor dato  1860 max 9958 min 19
# Valor dato  8142 max 9958 min 19
# Valor dato  5579 max 9958 min 19
# Valor dato  5884 max 9958 min 19
# Valor dato  1993 max 9958 min 19
# Valor dato  3205 max 9958 min 19
# Valor dato  7621 max 9958 min 19
# Valor dato  9567 max 9958 min 19
# Valor dato  2504 max 9958 min 19
# Valor dato  613 max 9958 min 19
# Valor dato  1961 max 9958 min 19
# Valor dato  2754 max 9958 min 19
# Valor dato  1326 max 9958 min 19
# Valor dato  4259 max 9958 min 19
# Valor dato  8944 max 9958 min 19
# Valor dato  8202 max 9958 min 19
# Valor dato  3202 max 9958 min 19
# Valor dato  3506 max 9958 min 19
# Valor dato  6784 max 9958 min 19
# Valor dato  2021 max 9958 min 19
# Valor dato  2842 max 9958 min 19
# Valor dato  868 max 9958 min 19
# Valor dato  9528 max 9958 min 19
# Valor dato  5189 max 9958 min 19
# Valor dato  8872 max 9958 min 19
# Valor dato  9908 max 9958 min 19
# Valor dato  9958 max 9958 min 19
# Valor dato  498 max 9958 min 19
# Valor dato  8036 max 9958 min 19
# Valor dato  8808 max 9958 min 19
# Valor dato  7753 max 9958 min 19
# Valor dato  5211 max 5736 min 27
# Valor dato  2292 max 9958 min 19
# Valor dato  5795 max 9958 min 19
# Valor dato  743 max 9958 min 19
# Valor dato  3144 max 9958 min 19
# Valor dato  2829 max 9958 min 19
# Valor dato  8390 max 9958 min 19
# Valor dato  1682 max 9958 min 19
# Valor dato  5340 max 9958 min 19
# Valor dato  3541 max 9958 min 19
# Valor dato  569 max 9958 min 19
# Valor dato  3826 max 9958 min 19
# Valor dato  4232 max 9958 min 19
# Valor dato  2261 max 9958 min 19
# Valor dato  6042 max 9958 min 19
# Valor dato  360 max 9958 min 19
# Valor dato  9117 max 9958 min 19
# Valor dato  8023 max 9958 min 19
# Valor dato  6761 max 9958 min 19
# Valor dato  81 max 9958 min 19
# Valor dato  6309 max 9958 min 19
# Valor dato  3190 max 9958 min 19
# Valor dato  5425 max 9958 min 19
# Valor dato  8996 max 9958 min 19
# Valor dato  6367 max 9958 min 19
# Valor dato  4677 max 9958 min 19
# Valor dato  4234 max 9958 min 19
# Valor dato  5857 max 9956 min 27
# Valor dato  7369 max 9956 min 19
# Valor dato  3459 max 9958 min 19
# Valor dato  3618 max 9958 min 19
# Valor dato  9438 max 9958 min 19
# Valor dato  8025 max 9958 min 19
# Valor dato  1388 max 9958 min 19
# Valor dato  3074 max 9958 min 19
# Valor dato  1233 max 9958 min 19
# Valor dato  8157 max 9958 min 19
# Valor dato  3681 max 9958 min 19
# Valor dato  3493 max 9958 min 19
# Valor dato  358 max 9958 min 19
# Valor dato  270 max 9958 min 19
# Valor dato  699 max 9958 min 19
# Valor dato  3417 max 9958 min 19
# Valor dato  1839 max 9958 min 19
# Valor dato  5569 max 9958 min 19
# Valor dato  8363 max 9958 min 19
# Valor dato  2622 max 9958 min 19
# Valor dato  8794 max 9958 min 19
# Valor dato  3173 max 9958 min 19
# Valor dato  9847 max 9958 min 19
# Valor dato  6431 max 9958 min 19
# Valor dato  7462 max 9958 min 19
# Valor dato  6682 max 9958 min 19
# Valor dato  690 max 9958 min 19
# Valor dato  1626 max 9958 min 19
# Valor dato  4524 max 9958 min 19
# Valor dato  6057 max 9958 min 19
# Valor dato  9614 max 9958 min 19
# Valor dato  3168 max 9958 min 19
# Valor dato  8205 max 9958 min 19
# Valor dato  358 max 9958 min 19
# Valor dato  6312 max 9958 min 19
# Valor dato  7386 max 9958 min 19
# Valor dato  5100 max 9958 min 19
# Valor dato  4346 max 9958 min 19
# Valor dato  2726 max 9958 min 19
# Valor dato  4994 max 9958 min 19
# Valor dato  4916 max 9958 min 19
# Valor dato  6552 max 9958 min 19
# Valor dato  5578 max 9958 min 19
# Valor dato  3529 max 9958 min 19
# Valor dato  8946 max 9958 min 19
# Valor dato  2290 max 9958 min 19
# Valor dato  2647 max 9958 min 19
# Valor dato  6970 max 9958 min 19
# Valor dato  9051 max 9958 min 19
# Valor dato  9080 max 9958 min 19
# Valor dato  9631 max 9958 min 19
# Valor dato  8593 max 9958 min 19
# Valor dato  857 max 9958 min 19
# Valor dato  8627 max 9958 min 19
# Valor dato  1312 max 9958 min 19
# Valor dato  1886 max 9958 min 19
# Valor dato  9214 max 9958 min 19
# Valor dato  8355 max 9958 min 19
# Valor dato  3512 max 9958 min 19
# Valor dato  90 max 9958 min 19
# Valor dato  4412 max 9958 min 19
# Valor dato  9479 max 9958 min 19
# Valor dato  9610 max 9958 min 19
# Valor dato  8969 max 9958 min 19
# Valor dato  6189 max 9958 min 19
# Valor dato  2274 max 9958 min 19
# Valor dato  6355 max 9958 min 19
# Valor dato  7641 max 9958 min 19
# Valor dato  6620 max 9958 min 19
# Valor dato  5433 max 9958 min 19
# Valor dato  8987 max 9958 min 19
# Valor dato  7888 max 9958 min 19
# Valor dato  8338 max 9958 min 19
# Valor dato  4566 max 9958 min 19
# Valor dato  7770 max 9958 min 19
# Valor dato  7284 max 9958 min 19
# Valor dato  6856 max 9958 min 19
# Valor dato  417 max 9958 min 19
# Valor dato  606 max 9958 min 19
# Valor dato  2260 max 9958 min 19
# Valor dato  5849 max 9958 min 19
# Valor dato  237 max 9958 min 19
# Valor dato  7205 max 9958 min 19
# Valor dato  3059 max 9958 min 19
# Valor dato  5217 max 9958 min 19
# Valor dato  8518 max 9958 min 19
# Valor dato  4945 max 9958 min 19
# Valor dato  783 max 9958 min 19
# Valor dato  6873 max 9958 min 19
# Valor dato  8458 max 9958 min 19
# Valor dato  873 max 9958 min 19
# Valor dato  7637 max 9958 min 19
# Valor dato  4289 max 9958 min 19
# Valor dato  483 max 9958 min 19
# Valor dato  6607 max 9958 min 19
# Valor dato  478 max 9958 min 19
# Valor dato  2757 max 9958 min 19
# Valor dato  9314 max 9958 min 19
# Valor dato  4471 max 9958 min 19
# Valor dato  0 max 5736 min 27
# Valor dato  4292 max 9958 min 19
# Valor dato  5791 max 9958 min 19
# Valor dato  5057 max 9958 min 19
# Valor dato  5115 max 9958 min 19
# Valor dato  1521 max 9958 min 19
# Valor dato  6157 max 9958 min 19
# Valor dato  8574 max 9958 min 19
# Valor dato  1491 max 9958 min 19
# Valor dato  1947 max 9958 min 19
# Valor dato  2951 max 9958 min 19
# Valor dato  9231 max 9958 min 19
# Valor dato  5021 max 9958 min 19
# Valor dato  537 max 9958 min 19
# Valor dato  3740 max 9958 min 19
# Valor dato  5054 max 9958 min 19
# Valor dato  4030 max 9958 min 19
# Valor dato  4098 max 9958 min 19
# Valor dato  5325 max 9958 min 19
# Valor dato  1081 max 9958 min 19
# Valor dato  7516 max 9958 min 19
# Valor dato  3516 max 9958 min 19
# Valor dato  3002 max 9958 min 19
# Valor dato  2231 max 9958 min 19
# Valor dato  6139 max 9958 min 19
# Valor dato  1796 max 9958 min 19
# Valor dato  5404 max 9958 min 19
# Valor dato  2338 max 9958 min 19
# Valor dato  4580 max 9958 min 19
# Valor dato  9218 max 9958 min 19
# Valor dato  9021 max 9958 min 19
# Valor dato  3970 max 9958 min 19
# Valor dato  2062 max 9956 min 19
# Valor dato  9862 max 9958 min 19
# Valor dato  4812 max 9958 min 19
# Valor dato  5379 max 9958 min 19
# Valor dato  4977 max 9958 min 19
# Valor dato  2685 max 9958 min 19
# Valor dato  1536 max 9958 min 19
# Valor dato  9904 max 9958 min 19
# Valor dato  4176 max 9958 min 19
# Valor dato  3483 max 9958 min 19
# Valor dato  9207 max 9958 min 19
# Valor dato  9759 max 9958 min 19
# Valor dato  4857 max 9958 min 19
# Valor dato  9744 max 9958 min 19
# Valor dato  3499 max 9958 min 19
# Valor dato  9911 max 9958 min 19
# Valor dato  127 max 9958 min 19
# Valor dato  3950 max 9958 min 19
# Valor dato  5236 max 9958 min 19
# Valor dato  7560 max 9958 min 19
# Valor dato  7818 max 9958 min 19
# Valor dato  5105 max 9958 min 19
# Valor dato  563 max 9958 min 19
# Valor dato  49 max 9958 min 19
# Valor dato  1244 max 9958 min 19
# Valor dato  8711 max 9958 min 19
# Valor dato  1805 max 9958 min 19
# Valor dato  9934 max 9958 min 19
# Valor dato  3291 max 9958 min 19
# Valor dato  7375 max 9958 min 19
# Valor dato  8955 max 9958 min 19
# Valor dato  3614 max 9958 min 19
# Valor dato  3589 max 9958 min 19
# Valor dato  3768 max 9958 min 19
# Valor dato  8993 max 9958 min 19
# Valor dato  4918 max 9958 min 19
# Valor dato  2805 max 9958 min 19
# Valor dato  6882 max 9958 min 19
# Valor dato  4822 max 9958 min 19
# Valor dato  6982 max 9958 min 19
# Valor dato  6717 max 9958 min 19
# Valor dato  4030 max 9958 min 19
# Valor dato  3093 max 9958 min 19
# Valor dato  1574 max 9958 min 19
# Valor dato  126 max 9958 min 19
# Valor dato  6593 max 9958 min 19
# Valor dato  1486 max 9958 min 19
# Valor dato  253 max 9958 min 19
# Valor dato  543 max 9958 min 19
# Valor dato  3074 max 9958 min 19
# Valor dato  7814 max 9958 min 19
# Valor dato  4713 max 9958 min 19
# Valor dato  8179 max 9958 min 19
# Valor dato  8377 max 9958 min 19
# Valor dato  4762 max 9958 min 19
# Valor dato  5775 max 9958 min 19
# Valor dato  7088 max 9958 min 19
# Valor dato  2919 max 9958 min 19
# Valor dato  5710 max 9958 min 19
# Valor dato  6732 max 9958 min 19
# Valor dato  294 max 9958 min 19
# Valor dato  1017 max 9958 min 19
# Valor dato  346 max 9958 min 19
# Valor dato  235 max 9958 min 19
# Valor dato  1137 max 9958 min 19
# Valor dato  5691 max 9958 min 19
# Valor dato  5153 max 9958 min 19
# Valor dato  3943 max 9958 min 19
# Valor dato  5060 max 9956 min 27
# Valor dato  0 max 492 min 492
# Valor dato  2573 max 9958 min 19
# Valor dato  6328 max 9958 min 19
# Valor dato  925 max 9958 min 19
# Valor dato  9291 max 9958 min 19
# Valor dato  6710 max 9958 min 19
# Valor dato  4018 max 9958 min 19
# Valor dato  7217 max 9958 min 19
# Valor dato  6836 max 9958 min 19
# Valor dato  6963 max 9958 min 19
# Valor dato  5055 max 9958 min 19
# Valor dato  7090 max 9958 min 19
# Valor dato  3858 max 9958 min 19
# Valor dato  8130 max 9958 min 19
# Valor dato  4904 max 9958 min 19
# Valor dato  8571 max 9958 min 19
# Valor dato  2661 max 9958 min 19
# Valor dato  9633 max 9958 min 19
# Valor dato  9685 max 9958 min 19
# Valor dato  4789 max 9958 min 19
# Valor dato  3073 max 9958 min 19
# Valor dato  2604 max 9958 min 19
# Valor dato  6851 max 9958 min 19
# Valor dato  9805 max 9958 min 19
# Valor dato  9250 max 9958 min 19
# Valor dato  7868 max 9958 min 19
# Valor dato  6503 max 9958 min 19
# Valor dato  9485 max 9958 min 19
# Valor dato  9006 max 9958 min 19
# Valor dato  2195 max 9958 min 19
# Valor dato  4639 max 9958 min 0
# Valor dato  2949 max 9958 min 0
# Valor dato  967 max 9958 min 0
# Valor dato  226 max 9958 min 0
# Valor dato  6763 max 9958 min 0
# Valor dato  7677 max 9958 min 0
# Valor dato  596 max 9958 min 0
# Valor dato  3981 max 9958 min 0
# Valor dato  865 max 9958 min 0
# Valor dato  7560 max 9958 min 0
# Valor dato  9036 max 9958 min 0
# Valor dato  7955 max 9958 min 0
# Valor dato  7770 max 9958 min 0
# Valor dato  3518 max 9958 min 0
# Valor dato  9211 max 9958 min 0
# Valor dato  6342 max 9958 min 0
# Valor dato  2532 max 9958 min 0
# Valor dato  5196 max 9958 min 0
# Valor dato  2379 max 9958 min 0
# Valor dato  7321 max 9958 min 0
# Valor dato  8270 max 9958 min 0
# Valor dato  4984 max 9958 min 0
# Valor dato  4172 max 9958 min 0
# Valor dato  4427 max 9958 min 0
# Valor dato  4234 max 9958 min 0
# Valor dato  2040 max 9958 min 0
# Valor dato  7283 max 9958 min 0
# Valor dato  72 max 9958 min 0
# Valor dato  7398 max 9958 min 0
# Valor dato  5830 max 9958 min 0
# Valor dato  1063 max 9958 min 0
# Valor dato  347 max 9958 min 0
# Valor dato  6950 max 9958 min 0
# Valor dato  5060 max 9956 min 27
# Valor dato  5218 max 9958 min 0
# Valor dato  8701 max 9958 min 0
# Valor dato  1703 max 9958 min 0
# Valor dato  4653 max 9958 min 0
# Valor dato  9933 max 9958 min 0
# Valor dato  907 max 9958 min 0
# Valor dato  3959 max 9958 min 0
# Valor dato  6728 max 9958 min 0
# Valor dato  2806 max 9958 min 0
# Valor dato  5797 max 9958 min 0
# Valor dato  8720 max 9958 min 0
# Valor dato  7084 max 9958 min 0
# Valor dato  1308 max 9958 min 0
# Valor dato  5334 max 9958 min 0
# Valor dato  8444 max 9956 min 27
# Valor dato  7487 max 9958 min 0
# Valor dato  9415 max 9958 min 0
# Valor dato  9296 max 9999 min 0
# Valor dato  8825 max 9999 min 0
# Valor dato  5404 max 9999 min 0
# Valor dato  8722 max 9999 min 0
# Valor dato  6892 max 9999 min 0
# Valor dato  297 max 9999 min 0
# Valor dato  32 max 9999 min 0
# Valor dato  9134 max 9999 min 0
# Valor dato  3181 max 9999 min 0
# Valor dato  8506 max 9999 min 0
# Valor dato  415 max 9999 min 0
# Valor dato  7057 max 9999 min 0
# Valor dato  2698 max 9999 min 0
# Valor dato  991 max 9999 min 0
# Valor dato  6376 max 9999 min 0
# Valor dato  8898 max 9999 min 0
# Valor dato  2715 max 9999 min 0
# Valor dato  1052 max 9999 min 0
# Valor dato  5171 max 9999 min 0
# Valor dato  8189 max 9999 min 0
# Valor dato  1559 max 9999 min 0
# Valor dato  2506 max 9999 min 0
# Valor dato  4010 max 9999 min 0
# Valor dato  9016 max 9999 min 0
# Valor dato  8224 max 9999 min 0
# Valor dato  3109 max 9999 min 0
# Valor dato  6539 max 9999 min 0
# Valor dato  0 max 9999 min 0
# Valor dato  3378 max 9999 min 0
# Valor dato  8109 max 9999 min 0
# Valor dato  2133 max 9958 min 19
# Valor dato  7483 max 9999 min 0
# Valor dato  5776 max 9999 min 0
# Valor dato  154 max 9999 min 0
# Valor dato  9157 max 9958 min 19
# Valor dato  9999 max 9999 min 0
# Valor dato  1962 max 9999 min 0
# Valor dato  8839 max 9999 min 0
# Valor dato  7490 max 9999 min 0
# Valor dato  1136 max 9999 min 0
# Valor dato  1360 max 9999 min 0
# Valor dato  8977 max 9999 min 0
# Valor dato  1309 max 9999 min 0
# Valor dato  2587 max 9999 min 0
# Valor dato  9932 max 9999 min 0
# Valor dato  3382 max 9999 min 0
# Valor dato  5021 max 9999 min 0
# Valor dato  4266 max 9999 min 0
# Valor dato  3563 max 9999 min 0
# Valor dato  8860 max 9999 min 0
# Valor dato  7373 max 8456 min 27
# Valor dato  9618 max 9999 min 0
# Valor dato  7643 max 9999 min 0
# Valor dato  337 max 9999 min 0
# Valor dato  928 max 9999 min 0
# Valor dato  6582 max 9999 min 0
# Valor dato  6621 max 9999 min 0
# Valor dato  4310 max 9999 min 0
# Valor dato  7955 max 9999 min 0
# Valor dato  888 max 9999 min 0
# Valor dato  4225 max 9999 min 0
# Valor dato  6815 max 9999 min 0
# Valor dato  4570 max 9999 min 0
# Valor dato  3437 max 9999 min 0
# Valor dato  853 max 9999 min 0
# Valor dato  8 max 9999 min 0
# Valor dato  7722 max 9999 min 0
# Valor dato  3682 max 9999 min 0
# Valor dato  492 max 492 min 492
# Valor dato  2350 max 9999 min 0
# Valor dato  8657 max 9999 min 0
# Valor dato  9097 max 9999 min 0
# Valor dato  3827 max 9999 min 0
# Valor dato  9126 max 9999 min 0
# Valor dato  1269 max 9999 min 0
# Valor dato  2071 max 9999 min 0
# Valor dato  6651 max 9999 min 0
# Valor dato  3149 max 9999 min 0
# Valor dato  910 max 9999 min 0
# Valor dato  528 max 9999 min 0
# Valor dato  639 max 9999 min 0
# Valor dato  8398 max 9999 min 0
# Valor dato  1888 max 9999 min 0
# Valor dato  6610 max 9999 min 0
# Valor dato  2393 max 9999 min 0
# Valor dato  1298 max 9999 min 0
# Valor dato  9211 max 9999 min 0
# Valor dato  7685 max 9999 min 0
# Valor dato  9086 max 9999 min 0
# Valor dato  4285 max 9999 min 0
# Valor dato  930 max 9999 min 0
# Valor dato  5990 max 9999 min 0
# Valor dato  4583 max 9999 min 0
# Valor dato  7314 max 9999 min 0
# Valor dato  1476 max 9999 min 0
# Valor dato  4116 max 9999 min 0
# Valor dato  5820 max 9999 min 0
# Valor dato  1892 max 9999 min 0
# Valor dato  7525 max 9999 min 0
# Valor dato  5528 max 9999 min 0
# Valor dato  7525 max 9999 min 0
# Valor dato  5053 max 9999 min 0
# Valor dato  5081 max 9999 min 0
# Valor dato  9114 max 9999 min 0
# Valor dato  1338 max 9999 min 0
# Valor dato  5989 max 9999 min 0
# Valor dato  9426 max 9999 min 0
# Valor dato  8067 max 9999 min 0
# Valor dato  5147 max 9999 min 0
# Valor dato  5223 max 9999 min 0
# Valor dato  6787 max 9999 min 0
# Valor dato  2231 max 9999 min 0
# Valor dato  6532 max 9999 min 0
# Valor dato  2122 max 9999 min 0
# Valor dato  1281 max 9999 min 0
# Valor dato  3875 max 9999 min 0
# Valor dato  4850 max 9999 min 0
# Valor dato  179 max 9999 min 0
# Valor dato  6590 max 9999 min 0
# Valor dato  2254 max 9999 min 0
# Valor dato  5350 max 9999 min 0
# Valor dato  1131 max 9999 min 0
# Valor dato  3813 max 9999 min 0
# Valor dato  7857 max 9999 min 0
# Valor dato  1494 max 9999 min 0
# Valor dato  9181 max 9999 min 0
# Valor dato  6081 max 9999 min 0
# Valor dato  4603 max 9999 min 0
# Valor dato  5720 max 9999 min 0
# Valor dato  2433 max 9999 min 0
# Valor dato  7982 max 9999 min 0
# Valor dato  551 max 9999 min 0
# Valor dato  2030 max 9999 min 0
# Valor dato  573 max 9999 min 0
# Valor dato  3714 max 9999 min 0
# Valor dato  6059 max 9999 min 0
# Valor dato  7522 max 9999 min 0
# Valor dato  4047 max 9999 min 0
# Valor dato  6924 max 9999 min 0
# Valor dato  5082 max 9999 min 0
# Valor dato  9435 max 9999 min 0
# Valor dato  1232 max 9999 min 0
# Valor dato  9204 max 9999 min 0
# Valor dato  2954 max 9999 min 0
# Valor dato  443 max 9999 min 0
# Valor dato  1898 max 9999 min 0
# Valor dato  5486 max 9999 min 0
# Valor dato  5640 max 9999 min 0
# Valor dato  4278 max 9999 min 0
# Valor dato  9159 max 9999 min 0
# Valor dato  262 max 9999 min 0
# Valor dato  9262 max 9999 min 0
# Valor dato  9683 max 9999 min 0
# Valor dato  1041 max 9999 min 0
# Valor dato  9848 max 9999 min 0
# Valor dato  1723 max 9999 min 0
# Valor dato  8324 max 9999 min 0
# Valor dato  7373 max 8456 min 27
# Valor dato  8537 max 8537 min 27
# Valor dato  3890 max 9999 min 0
# Valor dato  8976 max 9999 min 0
# Valor dato  5199 max 9999 min 0
# Valor dato  4552 max 9999 min 0
# Valor dato  6931 max 9999 min 0
# Valor dato  6087 max 9999 min 0
# Valor dato  8777 max 9999 min 0
# Valor dato  99 max 9999 min 0
# Valor dato  657 max 9999 min 0
# Valor dato  8566 max 9999 min 0
# Valor dato  952 max 9999 min 0
# Valor dato  7017 max 9999 min 0
# Valor dato  2641 max 9999 min 0
# Valor dato  2735 max 9999 min 0
# Valor dato  9368 max 9999 min 0
# Valor dato  1298 max 9999 min 0
# Valor dato  3195 max 9999 min 0
# Valor dato  6776 max 9999 min 0
# Valor dato  5805 max 9999 min 0
# Valor dato  5266 max 9999 min 0
# Valor dato  3428 max 9999 min 0
# Valor dato  9300 max 9999 min 0
# Valor dato  4324 max 8537 min 27
# Valor dato  6506 max 9999 min 0
# Valor dato  1638 max 9999 min 0
# Valor dato  3526 max 9956 min 27
# Valor dato  9956 max 9956 min 27
# Valor dato  9956 max 9956 min 27
# Valor dato  7281 max 9956 min 27
# Valor dato  4465 max 9999 min 0
# Valor dato  183 max 9999 min 0
# Valor dato  3886 max 9999 min 0
# Valor dato  4667 max 9999 min 0
# Valor dato  9364 max 9999 min 0
# Valor dato  1489 max 9999 min 0
# Valor dato  1032 max 9999 min 0
# Valor dato  4154 max 9999 min 0
# Valor dato  6104 max 9999 min 0
# Valor dato  9875 max 9999 min 0
# Valor dato  3679 max 9999 min 0
# Valor dato  6141 max 9999 min 0
# Valor dato  3412 max 9999 min 0
# Valor dato  2538 max 9999 min 0
# Valor dato  4969 max 9999 min 0
# Valor dato  636 max 9999 min 0
# Valor dato  6170 max 9999 min 0
# Valor dato  1956 max 9999 min 0
# Valor dato  2844 max 9999 min 0
# Valor dato  2760 max 9999 min 0
# Valor dato  2621 max 9999 min 0
# Valor dato  6649 max 9999 min 0
# Valor dato  4393 max 9999 min 0
# Valor dato  8954 max 9999 min 0
# Valor dato  3275 max 9956 min 19
# Valor dato  2528 max 9999 min 0
# Valor dato  925 max 9956 min 27
# Valor dato  6505 max 9956 min 27
# Valor dato  5729 max 9958 min 19
# Valor dato  1535 max 9999 min 0
# Valor dato  5155 max 9999 min 0
# Valor dato  0 max 9956 min 27
# Valor dato  8814 max 9956 min 27
# Valor dato  1729 max 9956 min 27
# Valor dato  4043 max 9956 min 27
# Valor dato  2761 max 9999 min 0
# Valor dato  140 max 9999 min 0
# Valor dato  50 max 9999 min 0
# Valor dato  7917 max 9956 min 19
# Valor dato  8468 max 9999 min 0
# Valor dato  3245 max 9999 min 0
# Valor dato  4067 max 5736 min 27
# Valor dato  1790 max 9999 min 0
# Valor dato  7289 max 9999 min 0
# Valor dato  1729 max 9956 min 27
# Valor dato  7281 max 9956 min 27
# Valor dato  9954 max 9999 min 0
# Valor dato  2573 max 9958 min 19
# Valor dato  8364 max 9999 min 0
# Valor dato  2042 max 9999 min 0
# Valor dato  5624 max 9999 min 0
# Valor dato  3919 max 9999 min 0
# Valor dato  109 max 9999 min 0
# Valor dato  9631 max 9999 min 0
# Valor dato  4673 max 9999 min 0
# Valor dato  4264 max 9999 min 0
# Valor dato  5735 max 9999 min 0
# Valor dato  4548 max 9999 min 0
# Valor dato  8823 max 9999 min 0
# Valor dato  1877 max 9999 min 0
# Valor dato  4313 max 9999 min 0
# Valor dato  6833 max 9999 min 0
# Valor dato  3198 max 9999 min 0
# Valor dato  4949 max 9999 min 0
# Valor dato  9355 max 9999 min 0
# Valor dato  7793 max 9999 min 0
# Valor dato  8156 max 9999 min 0
# Valor dato  1238 max 9999 min 0
# Valor dato  1551 max 9999 min 0
# Valor dato  4976 max 9999 min 0
# Valor dato  5383 max 9999 min 0
# Valor dato  19 max 9999 min 0
# Valor dato  3133 max 9999 min 0
# Valor dato  6343 max 9999 min 0
# Valor dato  9304 max 9999 min 0
# Valor dato  1956 max 9999 min 0
# Valor dato  5981 max 9999 min 0
# Valor dato  0 max 0 min 100000
# Valor dato  4067 max 5736 min 27
# Valor dato  6289 max 9999 min 0
# Valor dato  0 max 0 min 100000
# Valor dato  5060 max 9956 min 27
# Valor dato  0 max 492 min 27
# Valor dato  6125 max 9999 min 0
# Valor dato  7178 max 9956 min 27
# Valor dato  0 max 3426 min 27
# Valor dato  6868 max 9999 min 0
# Valor dato  5002 max 9999 min 0
# Valor dato  3174 max 9999 min 0
# Valor dato  9207 max 9999 min 0
# Valor dato  9718 max 9999 min 0
# Valor dato  5216 max 9999 min 0
# Valor dato  1183 max 9999 min 0
# Valor dato  2377 max 9999 min 0
# Valor dato  5487 max 9999 min 0
# Valor dato  7472 max 9999 min 0
# Valor dato  4573 max 9999 min 0
# Valor dato  2475 max 9999 min 0
# Valor dato  3666 max 9999 min 0
# Valor dato  8011 max 9999 min 0
# Valor dato  8967 max 9999 min 0
# Valor dato  6912 max 9999 min 0
# Valor dato  192 max 9999 min 0
# Valor dato  1729 max 9999 min 0
# Valor dato  902 max 9999 min 0
# Valor dato  8131 max 9999 min 0
# Valor dato  2933 max 9999 min 0
# Valor dato  3286 max 9999 min 0
# Valor dato  308 max 9999 min 0
# Valor dato  9593 max 9999 min 0
# Valor dato  7278 max 9999 min 0
# Valor dato  2197 max 9999 min 0
# Valor dato  2555 max 9999 min 0
# Valor dato  9672 max 9999 min 0
# Valor dato  774 max 9999 min 0
# Valor dato  6445 max 9999 min 0
# Valor dato  5000 max 9999 min 0
# Valor dato  2325 max 9999 min 0
# Valor dato  997 max 9999 min 0
# Valor dato  8283 max 9999 min 0
# Valor dato  8412 max 9999 min 0
# Valor dato  6127 max 9999 min 0
# Valor dato  8382 max 9999 min 0
# Valor dato  5421 max 9999 min 0
# Valor dato  4693 max 9999 min 0
# Valor dato  9334 max 9999 min 0
# Valor dato  2439 max 9999 min 0
# Valor dato  7334 max 9999 min 0
# Valor dato  8421 max 9999 min 0
# Valor dato  8159 max 9999 min 0
# Valor dato  4985 max 9999 min 0
# Valor dato  2957 max 9999 min 0
# Valor dato  1354 max 9999 min 0
# Valor dato  1761 max 9999 min 0
# Valor dato  8762 max 9999 min 0
# Valor dato  2972 max 9999 min 0
# Valor dato  1541 max 9999 min 0
# Valor dato  7716 max 9999 min 0
# Valor dato  1852 max 9999 min 0
# Valor dato  1850 max 9999 min 0
# Valor dato  3662 max 9999 min 0
# Valor dato  5060 max 9956 min 27
# Valor dato  27 max 492 min 27
# Valor dato  5211 max 5736 min 27
# Valor dato  0 max 0 min 100000
# Valor dato  8153 max 9999 min 0
# Valor dato  1726 max 9999 min 0
# Valor dato  5474 max 9999 min 0
# Valor dato  6980 max 9999 min 0
# Valor dato  5393 max 9999 min 0
# Valor dato  3485 max 9999 min 0
# Valor dato  5948 max 9999 min 0
# Valor dato  2305 max 9999 min 0
# Valor dato  30 max 9999 min 0
# Valor dato  4029 max 9999 min 0
# Valor dato  9559 max 9999 min 0
# Valor dato  6898 max 9999 min 0
# Valor dato  2160 max 9999 min 0
# Valor dato  4562 max 9999 min 0
# Valor dato  6424 max 9999 min 0
# Valor dato  0 max 0 min 100000
# Valor dato  5060 max 9956 min 27
# Valor dato  7279 max 9999 min 0
# Valor dato  94 max 9999 min 0
# Valor dato  9649 max 9999 min 0
# Valor dato  1499 max 9999 min 0
# Valor dato  2351 max 9999 min 0
# Valor dato  7339 max 9999 min 0
# Valor dato  7464 max 9999 min 0
# Valor dato  1742 max 9999 min 0
# Valor dato  7330 max 9999 min 0
# Valor dato  2086 max 9999 min 0
# Valor dato  7515 max 9999 min 0
# Valor dato  1349 max 9999 min 0
# Valor dato  9915 max 9999 min 0
# Valor dato  186 max 9999 min 0
# Valor dato  3881 max 9999 min 0
# Valor dato  7719 max 9999 min 0
# Valor dato  4280 max 9999 min 0
# Valor dato  1641 max 9999 min 0
# Valor dato  8902 max 9999 min 0
# Valor dato  3010 max 9999 min 0
# Valor dato  3480 max 9999 min 0
# Valor dato  2726 max 9999 min 0
# Valor dato  7583 max 9999 min 0
# Valor dato  8789 max 9999 min 0
# Valor dato  4140 max 9999 min 0
# Valor dato  3708 max 9999 min 0
# Valor dato  2723 max 9999 min 0
# Valor dato  938 max 9999 min 0
# Valor dato  2557 max 9999 min 0
# Valor dato  2493 max 9999 min 0
# Valor dato  431 max 9999 min 0
# Valor dato  710 max 9999 min 0
# Valor dato  4220 max 9999 min 0
# Valor dato  5905 max 9999 min 0
# Valor dato  7690 max 9999 min 0
# Valor dato  9613 max 9999 min 0
# Valor dato  9391 max 9999 min 0
# Valor dato  3638 max 9999 min 0
# Valor dato  8270 max 9999 min 0
# Valor dato  9421 max 9999 min 0
# Valor dato  7667 max 9999 min 0
# Valor dato  7829 max 9999 min 0
# Valor dato  2671 max 9999 min 0
# Valor dato  6180 max 9999 min 0
# Valor dato  8743 max 9999 min 0
# Valor dato  9095 max 9999 min 0
# Valor dato  3899 max 9999 min 0
# Valor dato  3024 max 9999 min 0
# Valor dato  5060 max 9956 min 27
# Valor dato  5634 max 9999 min 0
# Valor dato  4133 max 9999 min 0
# Valor dato  4387 max 9999 min 0
# Valor dato  2722 max 9999 min 0
# Valor dato  3287 max 9999 min 0
# Valor dato  6773 max 9999 min 0
# Valor dato  9643 max 9999 min 0
# Valor dato  1519 max 9999 min 0
# Valor dato  6742 max 9999 min 0
# Valor dato  5354 max 9999 min 0
# Valor dato  244 max 9999 min 0
# Valor dato  3124 max 9999 min 0
# Valor dato  139 max 9999 min 0
# Valor dato  6259 max 9999 min 0
# Valor dato  2063 max 9999 min 0
# Valor dato  7418 max 9999 min 0
# Valor dato  2443 max 9999 min 0
# Valor dato  6579 max 9999 min 0
# Valor dato  5361 max 9999 min 0
# Valor dato  1528 max 9999 min 0
# Valor dato  3378 max 9999 min 0
# Valor dato  4447 max 9999 min 0
# Valor dato  2700 max 9999 min 0
# Valor dato  4045 max 9999 min 0
# Valor dato  4882 max 9999 min 0
# Valor dato  5060 max 9956 min 27
# Valor dato  6948 max 9999 min 0
# Valor dato  4794 max 9999 min 0
# Valor dato  3036 max 9999 min 0
# Valor dato  8506 max 9999 min 0
# Valor dato  7107 max 9999 min 0
# Valor dato  6092 max 9999 min 0
# Valor dato  5417 max 9999 min 0
# Valor dato  9664 max 9999 min 0
# Valor dato  4882 max 9999 min 0
# Valor dato  3787 max 9999 min 0
# Valor dato  4899 max 9999 min 0
# Valor dato  5551 max 9999 min 0
# Valor dato  2589 max 9999 min 0
# Valor dato  1386 max 9999 min 0
# Valor dato  353 max 9999 min 0
# Valor dato  5165 max 9999 min 0
# Valor dato  6317 max 9999 min 0
# Valor dato  5060 max 9956 min 27
# Valor dato  27 max 492 min 27
# Valor dato  5060 max 9956 min 27
# Valor dato  6312 max 9999 min 0
# Valor dato  3931 max 9999 min 0
# Valor dato  9017 max 9999 min 0
# Valor dato  6709 max 9999 min 0
# Valor dato  5165 max 9999 min 0
# Valor dato  7069 max 9999 min 0
# Valor dato  6353 max 9999 min 0
# Valor dato  1712 max 9999 min 0
# Valor dato  5269 max 9999 min 0
# Valor dato  8705 max 9999 min 0
# Valor dato  5404 max 9999 min 0
# Valor dato  2733 max 9999 min 0
# Valor dato  6799 max 9999 min 0
# Valor dato  2734 max 9999 min 0
# Valor dato  4819 max 9999 min 0
# Valor dato  4315 max 9999 min 0
# Valor dato  435 max 9999 min 0
# Valor dato  1087 max 9999 min 0
# Valor dato  853 max 9999 min 0
# Valor dato  669 max 9999 min 0
# Valor dato  2450 max 9999 min 0
# Valor dato  6487 max 9999 min 0
# Valor dato  4802 max 9999 min 0
# Valor dato  6837 max 9999 min 0
# Valor dato  5562 max 9999 min 0
# Valor dato  8089 max 9999 min 0
# Valor dato  3610 max 9999 min 0
# Valor dato  5205 max 9999 min 0
# Valor dato  5960 max 9999 min 0
# Valor dato  6704 max 9999 min 0
# Valor dato  6911 max 9999 min 0
# Valor dato  2557 max 9999 min 0
# Valor dato  9829 max 9999 min 0
# Valor dato  3403 max 9999 min 0
# Valor dato  8816 max 9999 min 0
# Valor dato  1892 max 9999 min 0
# Valor dato  821 max 9999 min 0
# Valor dato  1522 max 9999 min 0
# Valor dato  7088 max 9999 min 0
# Valor dato  9154 max 9999 min 0
# Valor dato  2386 max 9999 min 0
# Valor dato  569 max 9999 min 0
# Valor dato  8232 max 9999 min 0
# Valor dato  9969 max 9999 min 0
# Valor dato  5710 max 9999 min 0
# Valor dato  2373 max 9999 min 0
# Valor dato  5482 max 9999 min 0
# Valor dato  399 max 9999 min 0
# Valor dato  6217 max 9999 min 0
# Valor dato  5154 max 9999 min 0
# Valor dato  1173 max 9999 min 0
# Valor dato  9015 max 9999 min 0
# Valor dato  6506 max 9999 min 0
# Valor dato  2030 max 9958 min 0
# Valor dato  5422 max 9956 min 19
# Valor dato  3584 max 9956 min 27
# Valor dato  8480 max 9999 min 0
# Valor dato  4166 max 9999 min 0
# Valor dato  5994 max 9999 min 0
# Valor dato  6354 max 9999 min 0
# Valor dato  4123 max 9999 min 0
# Valor dato  8437 max 9999 min 0
# Valor dato  2933 max 9999 min 0
# Valor dato  1608 max 9999 min 0
# Valor dato  2995 max 9999 min 0
# Valor dato  7422 max 9999 min 0
# Valor dato  1171 max 9999 min 0
# Valor dato  6295 max 9999 min 0
# Valor dato  8569 max 9999 min 0
# Valor dato  559 max 9999 min 0
# Valor dato  4801 max 9999 min 0
# Valor dato  5676 max 9999 min 0
# Valor dato  6652 max 9999 min 0
# Valor dato  6571 max 9999 min 0
# Valor dato  5340 max 9999 min 0
# Valor dato  8925 max 9999 min 0
# Valor dato  1743 max 9999 min 0
# Valor dato  172 max 9999 min 0
# Valor dato  3091 max 9999 min 0
# Valor dato  4089 max 9999 min 0
# Valor dato  6527 max 9999 min 0
# Valor dato  3566 max 9999 min 0
# Valor dato  8878 max 9999 min 0
# Valor dato  5812 max 9999 min 0
# Valor dato  3050 max 9999 min 0
# Valor dato  5196 max 9999 min 0
# Valor dato  2124 max 9999 min 0
# Valor dato  3333 max 9999 min 0
# Valor dato  4213 max 9999 min 0
# Valor dato  5186 max 9999 min 0
# Valor dato  8499 max 9999 min 0
# Valor dato  3370 max 9999 min 0
# Valor dato  6794 max 9999 min 0
# Valor dato  5568 max 9999 min 0
# Valor dato  5115 max 9999 min 0
# Valor dato  6141 max 9999 min 0
# Valor dato  9342 max 9999 min 0
# Valor dato  2639 max 9999 min 0
# Valor dato  2437 max 9999 min 0
# Valor dato  4263 max 9999 min 0
# Valor dato  3198 max 9999 min 0
# Valor dato  3590 max 9999 min 0
# Valor dato  9939 max 9999 min 0
# Valor dato  6202 max 9999 min 0
# Valor dato  6513 max 9999 min 0
# Valor dato  1631 max 9999 min 0
# Valor dato  5128 max 9999 min 0
# Valor dato  8257 max 9999 min 0
# Valor dato  1804 max 9999 min 0
# Valor dato  4571 max 9999 min 0
# Valor dato  2346 max 9999 min 0
# Valor dato  4683 max 9999 min 0
# Valor dato  8138 max 9999 min 0
# Valor dato  1225 max 9999 min 0
# Valor dato  495 max 9999 min 0
# Valor dato  7540 max 9999 min 0
# Valor dato  6421 max 9999 min 0
# Valor dato  6506 max 9999 min 0
# Valor dato  9851 max 9999 min 0
# Valor dato  6364 max 9999 min 0
# Valor dato  4790 max 9999 min 0
# Valor dato  8263 max 9999 min 0
# Valor dato  2491 max 9999 min 0
# Valor dato  3172 max 9999 min 0
# Valor dato  37 max 9999 min 0
# Valor dato  3537 max 9999 min 0
# Valor dato  8859 max 9999 min 0
# Valor dato  8828 max 9999 min 0
# Valor dato  871 max 9999 min 0
# Valor dato  7280 max 9999 min 0
# Valor dato  6987 max 9999 min 0
# Valor dato  5856 max 9999 min 0
# Valor dato  6590 max 9999 min 0
# Valor dato  8341 max 9999 min 0
# Valor dato  3970 max 9999 min 0
# Valor dato  5352 max 9999 min 0
# Valor dato  7665 max 9999 min 0
# Valor dato  5511 max 9999 min 0
# Valor dato  3069 max 9999 min 0
# Valor dato  9517 max 9999 min 0
# Valor dato  7361 max 9999 min 0
# Valor dato  3083 max 9999 min 0
# Valor dato  1351 max 9999 min 0
# Valor dato  6272 max 9999 min 0
# Valor dato  9122 max 9999 min 0
# Valor dato  4154 max 9999 min 0
# Valor dato  7335 max 9999 min 0
# Valor dato  5821 max 9999 min 0
# Valor dato  7457 max 9999 min 0
# Valor dato  9365 max 9999 min 0
# Valor dato  2747 max 9999 min 0
# Valor dato  1171 max 9999 min 0
# Valor dato  1776 max 9999 min 0
# Valor dato  269 max 9999 min 0
# Valor dato  2698 max 9958 min 0
# Valor dato  5825 max 9999 min 0
# Valor dato  7542 max 9999 min 0
# Valor dato  216 max 9999 min 0
# Valor dato  2339 max 9999 min 0
# Valor dato  9174 max 9999 min 0
# Valor dato  5344 max 9999 min 0
# Valor dato  596 max 9999 min 0
# Valor dato  7330 max 9999 min 0
# Valor dato  6267 max 9999 min 0
# Valor dato  9294 max 9999 min 0
# Valor dato  2013 max 9999 min 0
# Valor dato  757 max 9999 min 0
# Valor dato  519 max 9999 min 0
# Valor dato  8860 max 9999 min 0
# Valor dato  4650 max 9999 min 0
# Valor dato  3292 max 9999 min 0
# Valor dato  7832 max 9999 min 0
# Valor dato  1876 max 9999 min 0
# Valor dato  279 max 9999 min 0
# Valor dato  1990 max 9999 min 0
# Valor dato  3953 max 9999 min 0
# Valor dato  635 max 9999 min 0
# Valor dato  9295 max 9999 min 0
# Valor dato  1598 max 9999 min 0
# Valor dato  6107 max 9999 min 0
# Valor dato  2741 max 9999 min 0
# Valor dato  4937 max 9999 min 0
# Valor dato  570 max 9999 min 0
# Valor dato  4976 max 9999 min 0
# Valor dato  2540 max 9999 min 0
# Valor dato  4584 max 9999 min 0
# Valor dato  801 max 9999 min 0
# Valor dato  83 max 9999 min 0
# Valor dato  4800 max 9999 min 0
# Valor dato  9492 max 9999 min 0
# Valor dato  5609 max 9999 min 0
# Valor dato  6496 max 9999 min 0
# Valor dato  6440 max 9999 min 0
# Valor dato  2939 max 9999 min 0
# Valor dato  2763 max 9999 min 0
# Valor dato  5735 max 9999 min 0
# Valor dato  1304 max 9999 min 0
# Valor dato  9873 max 9999 min 0
# Valor dato  2606 max 9999 min 0
# Valor dato  164 max 9999 min 0
# Valor dato  4523 max 9999 min 0
# Valor dato  2251 max 9999 min 0
# Valor dato  9912 max 9999 min 0
# Valor dato  2272 max 9999 min 0
# Valor dato  2530 max 9999 min 0
# Valor dato  6339 max 9999 min 0
# Valor dato  6704 max 9999 min 0
# Valor dato  3165 max 9999 min 0
# Valor dato  1986 max 9999 min 0
# Valor dato  8302 max 9999 min 0
# Valor dato  5625 max 9999 min 0
# Valor dato  1079 max 9999 min 0
# Valor dato  9591 max 9999 min 0
# Valor dato  2547 max 9999 min 0
# Valor dato  2407 max 9999 min 0
# Valor dato  8484 max 9999 min 0
# Valor dato  7131 max 9999 min 0
# Valor dato  9561 max 9999 min 0
# Valor dato  4919 max 9999 min 0
# Valor dato  1931 max 9999 min 0
# Valor dato  3058 max 5736 min 27
# Valor dato  8972 max 9999 min 0
# Valor dato  7226 max 9999 min 0
# Valor dato  634 max 9999 min 0
# Valor dato  5771 max 9956 min 27
# Valor dato  9752 max 9999 min 0
# Valor dato  7409 max 9999 min 0
# Valor dato  4158 max 9999 min 0
# Valor dato  5725 max 9999 min 0
# Valor dato  356 max 9999 min 0
# Valor dato  952 max 9999 min 0
# Valor dato  7645 max 9999 min 0
# Valor dato  5472 max 9999 min 0
# Valor dato  3446 max 9999 min 0
# Valor dato  3339 max 9999 min 0
# Valor dato  8111 max 9999 min 0
# Valor dato  5883 max 9999 min 0
# Valor dato  7603 max 9999 min 0
# Valor dato  4486 max 9999 min 0
# Valor dato  3018 max 9999 min 0
# Valor dato  8752 max 9999 min 0
# Valor dato  6463 max 9999 min 0
# Valor dato  4098 max 9999 min 0
# Valor dato  4695 max 9999 min 0
# Valor dato  9010 max 9999 min 0
# Valor dato  6505 max 9999 min 0
# Valor dato  3179 max 9999 min 0
# Valor dato  6142 max 9999 min 0
# Valor dato  4547 max 9999 min 0
# ...
# Valor dato  7335 max 9999 min 0
# Valor dato  9384 max 9999 min 0
# Valor dato  6038 max 9999 min 0
# Valor dato  7417 max 9999 min 0
# Valor dato  7551 max 9999 min 0
# Valor dato  5083 max 9999 min 0
# Valor dato  6852 max 9999 min 0
# Valor dato  161 max 9999 min 0
# Valor dato  6452 max 9999 min 0
# Valor dato  1664 max 9999 min 0
# Valor dato  3939 max 9999 min 0
# Valor dato  4677 max 9999 min 0
# Valor dato  2033 max 9999 min 0
# Valor dato  99 max 9999 min 0
# Valor dato  1229 max 9999 min 0
# Valor dato  9500 max 9999 min 0
# Valor dato  23 max 9999 min 0
# Valor dato  7619 max 9999 min 0
# Valor dato  292 max 9999 min 0
# Valor dato  6823 max 9999 min 0
# Valor dato  668 max 9999 min 0
# Valor dato  5081 max 9999 min 0
# Valor dato  1652 max 9999 min 0
# Valor dato  5714 max 9999 min 0
# Valor dato  2481 max 9999 min 0
# Valor dato  8747 max 9999 min 0
# Valor dato  5436 max 9999 min 0
# Valor dato  2805 max 9999 min 0
# Valor dato  1485 max 9999 min 0
# Valor dato  9146 max 9999 min 0
# Valor dato  9877 max 9999 min 0
# Valor dato  968 max 9999 min 0
# Valor dato  9078 max 9999 min 0
# Valor dato  2729 max 9999 min 0
# Valor dato  6081 max 9999 min 0
# Valor dato  7335 max 9999 min 0
# Valor dato  8850 max 9999 min 0
# Valor dato  7267 max 9999 min 0
# Valor dato  6917 max 9999 min 0
# Valor dato  2754 max 9999 min 0
# Valor dato  1360 max 9999 min 0
# Valor dato  8693 max 9999 min 0
# Valor dato  1048 max 9999 min 0
# Valor dato  8460 max 9999 min 0
# Valor dato  323 max 9999 min 0
# Valor dato  6386 max 9999 min 0
# Valor dato  5812 max 9999 min 0
# Valor dato  3114 max 9999 min 0
# Valor dato  9561 max 9999 min 0
# Valor dato  4959 max 9999 min 0
# Valor dato  2548 max 9999 min 0
# Valor dato  7414 max 9999 min 0
# Valor dato  9078 max 9999 min 0
# Valor dato  6291 max 9999 min 0
# Valor dato  9879 max 9999 min 0
# Valor dato  6975 max 9999 min 0
# Valor dato  6669 max 9999 min 0
# Valor dato  6139 max 9999 min 0
# Valor dato  23 max 9999 min 0
# Valor dato  8649 max 9999 min 0
# Valor dato  1151 max 9999 min 0
# Valor dato  3713 max 9999 min 0
# Valor dato  4918 max 9999 min 0
# Valor dato  5290 max 9999 min 0
# Valor dato  4072 max 9999 min 0
# Valor dato  3497 max 9999 min 0
# Valor dato  8977 max 9999 min 0
# Valor dato  23 max 9999 min 0
# Valor dato  2606 max 9999 min 0
# Valor dato  5199 max 9999 min 0
# Valor dato  6194 max 9999 min 0
# Valor dato  8897 max 9999 min 0
# Valor dato  2567 max 9999 min 0
# Valor dato  2425 max 9999 min 0
# Valor dato  8184 max 9999 min 0
# Valor dato  3738 max 9999 min 0
# Valor dato  9808 max 9999 min 0
# Valor dato  200 max 9999 min 0
# Valor dato  1114 max 9999 min 0
# Valor dato  8751 max 9999 min 0
# Valor dato  170 max 9999 min 0
# Valor dato  1677 max 9999 min 0
# Valor dato  4053 max 9999 min 0
# Valor dato  2910 max 9999 min 0
# Valor dato  2213 max 9999 min 0
# Valor dato  4587 max 9999 min 0
# Valor dato  2935 max 9999 min 0
# Valor dato  3171 max 9999 min 0
# Valor dato  5050 max 9999 min 0
# Valor dato  548 max 9999 min 0
# Valor dato  7660 max 9999 min 0
# Valor dato  8221 max 9999 min 0
# Valor dato  1014 max 9999 min 0
# Valor dato  3208 max 9999 min 0
# Valor dato  5342 max 9999 min 0
# Valor dato  2617 max 9999 min 0
# Valor dato  6512 max 9999 min 0
# Valor dato  8274 max 9999 min 0
# Valor dato  7600 max 9999 min 0
# Valor dato  2271 max 9999 min 0
# Valor dato  1046 max 9999 min 0
# Valor dato  2559 max 9999 min 0
# Valor dato  4819 max 9999 min 0
# Valor dato  939 max 9999 min 0
# Valor dato  3750 max 9999 min 0
# Valor dato  3794 max 9999 min 0
# Valor dato  6038 max 9999 min 0
# Valor dato  5538 max 9999 min 0
# Valor dato  6599 max 9999 min 0
# Valor dato  7523 max 9999 min 0
# Valor dato  3138 max 9999 min 0
# Valor dato  6975 max 9999 min 0
# Valor dato  9808 max 9999 min 0
# Valor dato  7607 max 9999 min 0
# Valor dato  4135 max 9999 min 0
# Valor dato  2098 max 9999 min 0
# Valor dato  990 max 9999 min 0
# Valor dato  7588 max 9999 min 0
# Valor dato  5391 max 9999 min 0
# Valor dato  2032 max 9999 min 0
# Valor dato  5614 max 9999 min 0
# Valor dato  9699 max 9999 min 0
# Valor dato  2635 max 9999 min 0
# Valor dato  1686 max 9999 min 0
# Valor dato  4113 max 9999 min 0
# Valor dato  5548 max 9999 min 0
# Valor dato  7120 max 9999 min 0
# Valor dato  5251 max 9999 min 0
# Valor dato  3304 max 9999 min 0
# Valor dato  1192 max 9999 min 0
# Valor dato  5657 max 9999 min 0
# Valor dato  6214 max 9999 min 0
# Valor dato  3405 max 9999 min 0
# Valor dato  6389 max 9999 min 0
# Valor dato  1312 max 9999 min 0
# Valor dato  6624 max 9999 min 0
# Valor dato  6103 max 9999 min 0
# Valor dato  4292 max 9999 min 0
# Valor dato  8175 max 9999 min 0
# Valor dato  2297 max 9999 min 0
# Valor dato  9541 max 9999 min 0
# Valor dato  742 max 9999 min 0
# Valor dato  1074 max 9999 min 0
# Valor dato  7725 max 9999 min 0
# Valor dato  7697 max 9999 min 0
# Valor dato  4812 max 9999 min 0
# Valor dato  3200 max 9999 min 0
# Valor dato  8402 max 9999 min 0
# Valor dato  2344 max 9999 min 0
# Valor dato  4714 max 9999 min 0
# Valor dato  4645 max 9999 min 0
# Valor dato  9179 max 9999 min 0
# Valor dato  104 max 9999 min 0
# Valor dato  6731 max 9999 min 0
# Valor dato  1236 max 9999 min 0
# Valor dato  7711 max 9999 min 0
# Valor dato  866 max 9999 min 0
# Valor dato  3334 max 9999 min 0
# Valor dato  3171 max 9999 min 0
# Valor dato  3082 max 9999 min 0
# Valor dato  7177 max 9999 min 0
# Valor dato  2291 max 9999 min 0
# Valor dato  3023 max 9999 min 0
# Valor dato  8252 max 9999 min 0
# Valor dato  6368 max 9999 min 0
# Valor dato  720 max 9999 min 0
# Valor dato  3064 max 9999 min 0
# Valor dato  9569 max 9999 min 0
# Valor dato  9123 max 9999 min 0
# Valor dato  1761 max 9999 min 0
# Valor dato  635 max 9999 min 0
# Valor dato  120 max 9999 min 0
# Valor dato  940 max 9999 min 0
# Valor dato  7091 max 9999 min 0
# Valor dato  6851 max 9999 min 0
# Valor dato  2177 max 9999 min 0
# Valor dato  1155 max 9999 min 0
# Valor dato  7718 max 9999 min 0
# Valor dato  1863 max 9999 min 0
# Valor dato  6208 max 9999 min 0
# Valor dato  2524 max 9999 min 0
# Valor dato  6941 max 9999 min 0
# Valor dato  5998 max 9999 min 0
# Valor dato  7852 max 9999 min 0
# Valor dato  9297 max 9999 min 0
# Valor dato  1718 max 9999 min 0
# Valor dato  8424 max 9999 min 0
# Valor dato  7755 max 9999 min 0
# Valor dato  9471 max 9999 min 0
# Valor dato  6952 max 9999 min 0
# Valor dato  506 max 9999 min 0
# Valor dato  5400 max 9999 min 0
# Valor dato  4130 max 9999 min 0
# Valor dato  9149 max 9999 min 0
# Valor dato  8423 max 9999 min 0
# Valor dato  4113 max 9999 min 0
# Valor dato  9720 max 9999 min 0
# Valor dato  5518 max 9999 min 0
# Valor dato  5495 max 9999 min 0
# Valor dato  1798 max 9999 min 0
# Valor dato  1439 max 9999 min 0
# Valor dato  970 max 9999 min 0
# Valor dato  8426 max 9999 min 0
# Valor dato  1091 max 9999 min 0
# Valor dato  852 max 9999 min 0
# Valor dato  5518 max 9999 min 0
# Valor dato  4294 max 9999 min 0
# Valor dato  9381 max 9999 min 0
# Valor dato  6673 max 9999 min 0
# Valor dato  8364 max 9999 min 0
# Valor dato  1244 max 9999 min 0
# Valor dato  9233 max 9999 min 0
# Valor dato  889 max 9999 min 0
# Valor dato  8186 max 9999 min 0
# Valor dato  5232 max 9999 min 0
# Valor dato  6538 max 9999 min 0
# Valor dato  6256 max 9999 min 0
# Valor dato  8 max 9999 min 0
# Valor dato  4293 max 9999 min 0
# Valor dato  3312 max 9999 min 0
# Valor dato  1151 max 9999 min 0
# Valor dato  6925 max 9999 min 0
# Valor dato  7927 max 9999 min 0
# Valor dato  742 max 9999 min 0
# Valor dato  1015 max 9999 min 0
# Valor dato  3138 max 9999 min 0
# Valor dato  5222 max 9999 min 0
# Valor dato  8570 max 9999 min 0
# Valor dato  2050 max 9999 min 0
# Valor dato  41 max 9999 min 0
# Valor dato  3382 max 9999 min 0
# Valor dato  3452 max 9999 min 0
# Valor dato  6941 max 9999 min 0
# Valor dato  1042 max 9999 min 0
# Valor dato  8026 max 9999 min 0
# Valor dato  4307 max 9999 min 0
# Valor dato  3334 max 9999 min 0
# Valor dato  8721 max 9999 min 0
# Valor dato  8325 max 9999 min 0
# Valor dato  603 max 9999 min 0
# Valor dato  5475 max 9999 min 0
# Valor dato  4353 max 9999 min 0
# Valor dato  7532 max 9999 min 0
# Valor dato  1514 max 9999 min 0
# Valor dato  6243 max 9999 min 0
# Valor dato  483 max 9999 min 0
# Valor dato  9037 max 9999 min 0
# Valor dato  5733 max 9999 min 0
# Valor dato  5053 max 9999 min 0
# Valor dato  8454 max 9999 min 0
# Valor dato  8726 max 9999 min 0
# Valor dato  3438 max 9999 min 0
# Valor dato  420 max 9999 min 0
# Valor dato  4777 max 9999 min 0
# Valor dato  2425 max 9999 min 0
# Valor dato  2106 max 9999 min 0
# Valor dato  1401 max 9999 min 0
# Valor dato  8528 max 9999 min 0
# Valor dato  2750 max 9999 min 0
# Valor dato  8423 max 9999 min 0
# Valor dato  3610 max 9999 min 0
# Valor dato  7886 max 9999 min 0
# Valor dato  2036 max 9999 min 0
# Valor dato  6164 max 9999 min 0
# Valor dato  8738 max 9999 min 0
# Valor dato  7554 max 9999 min 0
# Valor dato  6810 max 9999 min 0
# Valor dato  8119 max 9999 min 0
# Valor dato  579 max 9999 min 0
# Valor dato  5175 max 9999 min 0
# Valor dato  5716 max 9999 min 0
# Valor dato  6165 max 9999 min 0
# Valor dato  603 max 9999 min 0
# Valor dato  1490 max 9999 min 0
# Valor dato  3621 max 9999 min 0
# Valor dato  6076 max 9999 min 0
# Valor dato  8000 max 9999 min 0
# Valor dato  1378 max 9999 min 0
# Valor dato  2028 max 9999 min 0
# Valor dato  6591 max 9999 min 0
# Valor dato  8800 max 9999 min 0
# Valor dato  2779 max 9999 min 0
# Valor dato  9013 max 9999 min 0
# Valor dato  3664 max 9999 min 0
# Valor dato  183 max 9999 min 0
# Valor dato  3691 max 9999 min 0
# Valor dato  7408 max 9999 min 0
# Valor dato  9758 max 9999 min 0
# Valor dato  6119 max 9999 min 0
# Valor dato  9128 max 9999 min 0
# Valor dato  2943 max 9999 min 0
# Valor dato  3620 max 9999 min 0
# Valor dato  5086 max 9999 min 0
# Valor dato  8164 max 9999 min 0
# Valor dato  9989 max 9999 min 0
# Valor dato  9782 max 9999 min 0
# Valor dato  7292 max 9999 min 0
# Valor dato  6816 max 9999 min 0
# Valor dato  5302 max 9999 min 0
# Valor dato  7000 max 9999 min 0
# Valor dato  5171 max 9999 min 0
# Valor dato  6538 max 9999 min 0
# Valor dato  9224 max 9999 min 0
# Valor dato  2293 max 9999 min 0
# Valor dato  9198 max 9999 min 0
# Valor dato  2416 max 9999 min 0
# Valor dato  254 max 9999 min 0
# Valor dato  1397 max 9999 min 0
# Valor dato  8954 max 9999 min 0
# Valor dato  6510 max 9999 min 0
# Valor dato  7757 max 9999 min 0
# Valor dato  9599 max 9999 min 0
# Valor dato  8590 max 9999 min 0
# Valor dato  1069 max 9999 min 0
# Valor dato  751 max 9999 min 0
# Valor dato  6070 max 9999 min 0
# Valor dato  4864 max 9999 min 0
# Valor dato  1052 max 9999 min 0
# Valor dato  7480 max 9999 min 0
# Valor dato  7442 max 9999 min 0
# Valor dato  301 max 9999 min 0
# Valor dato  2255 max 9999 min 0
# Valor dato  6176 max 9999 min 0
# Valor dato  5819 max 9999 min 0
# Valor dato  7750 max 9999 min 0
# Valor dato  4327 max 9999 min 0
# Valor dato  3610 max 9999 min 0
# Valor dato  8259 max 9999 min 0
# Valor dato  5156 max 9999 min 0
# Valor dato  3926 max 9999 min 0
# Valor dato  7480 max 9999 min 0
# Valor dato  8800 max 9999 min 0
# Valor dato  1694 max 9999 min 0
# Valor dato  9502 max 9999 min 0
# Valor dato  7445 max 9999 min 0
# Valor dato  9723 max 9999 min 0
# Valor dato  8700 max 9999 min 0
# Valor dato  8519 max 9999 min 0
# Valor dato  5752 max 9999 min 0
# Valor dato  5629 max 9999 min 0
# Valor dato  5269 max 9999 min 0
# Valor dato  1076 max 9999 min 0
# Valor dato  1357 max 9999 min 0
# Valor dato  7502 max 9999 min 0
# Valor dato  5413 max 9999 min 0
# Valor dato  7102 max 9999 min 0
# Valor dato  3566 max 9999 min 0
# Valor dato  9794 max 9999 min 0
# Valor dato  255 max 9999 min 0
# Valor dato  2092 max 9999 min 0
# Valor dato  293 max 9999 min 0
# Valor dato  1527 max 9999 min 0
# Valor dato  7209 max 9999 min 0
# Valor dato  765 max 9999 min 0
# Valor dato  2607 max 9999 min 0
# Valor dato  491 max 9999 min 0
# Valor dato  7577 max 9999 min 0
# Valor dato  668 max 9999 min 0
# Valor dato  3888 max 9999 min 0
# Valor dato  792 max 9999 min 0
# Valor dato  1159 max 9999 min 0
# Valor dato  3253 max 9999 min 0
# Valor dato  2460 max 9999 min 0
# Valor dato  7417 max 9999 min 0
# Valor dato  4854 max 9999 min 0
# Valor dato  2460 max 9999 min 0
# Valor dato  3468 max 9999 min 0
# Valor dato  2834 max 9999 min 0
# Valor dato  2416 max 9999 min 0
# Valor dato  7593 max 9999 min 0
# Valor dato  8566 max 9999 min 0
# Valor dato  2884 max 9999 min 0
# Valor dato  1447 max 9999 min 0
# Valor dato  331 max 9999 min 0
# Valor dato  6338 max 9999 min 0
# Valor dato  5014 max 9999 min 0
# Valor dato  125 max 9999 min 0
# Valor dato  2945 max 9999 min 0
# Valor dato  3458 max 9999 min 0
# Valor dato  6771 max 9999 min 0
# Valor dato  1833 max 9999 min 0
# Valor dato  1465 max 9999 min 0
# Valor dato  8576 max 9999 min 0
# Valor dato  2672 max 9999 min 0
# Valor dato  7221 max 9999 min 0
# Valor dato  6271 max 9999 min 0
# Valor dato  9030 max 9999 min 0
# Valor dato  2834 max 9999 min 0
# Valor dato  1918 max 9999 min 0
# Valor dato  9366 max 9999 min 0
# Valor dato  7600 max 9999 min 0
# Valor dato  1916 max 9999 min 0
# Valor dato  4783 max 9999 min 0
# Valor dato  9414 max 9999 min 0
# Valor dato  5375 max 9999 min 0
# Valor dato  1554 max 9999 min 0
# Valor dato  7599 max 9999 min 0
# Valor dato  6043 max 9999 min 0
# Valor dato  5442 max 9999 min 0
# Valor dato  8392 max 9999 min 0
# Valor dato  3554 max 9999 min 0
# Valor dato  3260 max 9999 min 0
# Valor dato  7997 max 9999 min 0
# Valor minimo  0
# Valor maximo  9999
# Valor avg  49970844
# Elemento número 0  valor 6944
# Elemento número 1  valor 2059
# Elemento número 2  valor 4206
# Elemento número 3  valor 2435
# Elemento número 4  valor 3447
# Elemento número 5  valor 3427
# Elemento número 6  valor 3910
# Elemento número 7  valor 9802
# Elemento número 8  valor 9909
# Elemento número 9  valor 5062
# Elemento número 10  valor 9867
# Elemento número 11  valor 8702
# Elemento número 12  valor 8322
# Elemento número 13  valor 7195
# Elemento número 14  valor 3341
# Elemento número 15  valor 8121
# Elemento número 16  valor 766
# Elemento número 17  valor 3120
# Elemento número 18  valor 9382
# Elemento número 19  valor 4071
# Elemento número 20  valor 732
# Elemento número 21  valor 6887
# Elemento número 22  valor 7928
# Elemento número 23  valor 5729
# Elemento número 24  valor 2886
# Elemento número 25  valor 8036
# Elemento número 26  valor 3559
# Elemento número 27  valor 5728
# Elemento número 28  valor 7392
# Elemento número 29  valor 3223
# Elemento número 30  valor 2428
# Elemento número 31  valor 1719
# Elemento número 32  valor 6833
# Elemento número 33  valor 7501
# Elemento número 34  valor 9606
# Elemento número 35  valor 5221
# Elemento número 36  valor 17
# Elemento número 37  valor 4696
# Elemento número 38  valor 9128
# Elemento número 39  valor 6827
# Elemento número 40  valor 9168
# Elemento número 41  valor 9707
# Elemento número 42  valor 8354
# Elemento número 43  valor 4884
# Elemento número 44  valor 5872
# Elemento número 45  valor 8028
# Elemento número 46  valor 4722
# Elemento número 47  valor 6029
# Elemento número 48  valor 576
# Elemento número 49  valor 6750
# Elemento número 50  valor 8972
# Elemento número 51  valor 5728
# Elemento número 52  valor 5881
# Elemento número 53  valor 4337
# Elemento número 54  valor 5744
# Elemento número 55  valor 6064
# Elemento número 56  valor 8028
# Elemento número 57  valor 3153
# Elemento número 58  valor 2174
# Elemento número 59  valor 499
# Elemento número 60  valor 2281
# Elemento número 61  valor 5117
# Elemento número 62  valor 471
# Elemento número 63  valor 7367
# Elemento número 64  valor 3281
# Elemento número 65  valor 460
# Elemento número 66  valor 3501
# Elemento número 67  valor 574
# Elemento número 68  valor 4854
# Elemento número 69  valor 7616
# Elemento número 70  valor 1343
# Elemento número 71  valor 6
# Elemento número 72  valor 9311
# Elemento número 73  valor 845
# Elemento número 74  valor 3804
# Elemento número 75  valor 9034
# Elemento número 76  valor 5898
# Elemento número 77  valor 2323
# Elemento número 78  valor 9366
# Elemento número 79  valor 5158
# Elemento número 80  valor 9408
# Elemento número 81  valor 893
# Elemento número 82  valor 9103
# Elemento número 83  valor 7974
# Elemento número 84  valor 130
# Elemento número 85  valor 550
# Elemento número 86  valor 8306
# Elemento número 87  valor 7997
# Elemento número 88  valor 8482
# Elemento número 89  valor 5932
# Elemento número 90  valor 5218
# Elemento número 91  valor 1105
# Elemento número 92  valor 4962
# Elemento número 93  valor 8103
# Elemento número 94  valor 4573
# Elemento número 95  valor 7797
# Elemento número 96  valor 21
# Elemento número 97  valor 292
# Elemento número 98  valor 9307
# Elemento número 99  valor 9430
